# %%
"""
Get articles/texts, and filter only sentences with white-listed vocab OR named entities.

Contents:
-load packages
-create helper functions
-data intialization from csv file of words &
 extend vocab set
-build data structure to house info moving forward
-write to .json formats
-read from existing .json formats
-get white-listed of words and inflections
-scrape journale en francais facile
"""

# %%
import bs4, requests, sys, codecs, urllib.request, re
from bs4 import SoupStrainer
from bs4.element import Comment
import random
import string
import json
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import mlconjug3
import sklearn
import goslate
from nltk.tokenize import word_tokenize, sent_tokenize
import pprint
pp = pprint.PrettyPrinter()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 0)
import mitosheet
import translators as ts
# Out:
# Using state Washington server backend.

# %%
def add_noun(add_word):

    if add_word[len(add_word)-1] != 's' and add_word[len(add_word)-1] != 'x':

        out_word = add_word + 's'

        return out_word
    else:
        return add_word

# %%
##METHODS

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = bs4.BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)



user_agent = 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'
headers={'User-Agent':user_agent,}

# %%
def get_known(unknown_list):
    
    count_got = 0
    known_list = []
    count_checked = 0
    for word in unknown_list:
        count_checked += 1
        decision = str(input(word+"\nKnown =k"))
        if decision =='k':
            known_list.append(word)
            count_got +=1
            print("got "+str(count_got))
        elif decision=='q':
            break
        print(str(len(unknown_list)-count_checked)+' remaining')
    return known_list

# %%
def review_out(out_dict,prev_learned,eb_unk_in,eb_unk_m_in,examples,counters):
    """
    out_dict = out
    prev_learned = eb_learned
    eb_unk_in =  eb_unk
    eb_unk_m_in = eb_unk_morph
    examples = eb_unk_examples
    
    decisions:
    k = word known, remove from eb_unk and eb_unk_morph
        and add to eb_learned
        
    m = remove morph from eb_unk and eb_unk_morph 
    
    a = add example to eb_unk_examples
    q = quit for day
    """
    
    for word in out_dict.keys():
        print("Lemma: "+word)
        print('')
        print("Morph: "+str(out_dict[word]['morph']))

        if len(examples[word])>0:
            print("Previous examples: ")
            for sent in examples[word]:
                print(" - "+sent)

        print("New examples: ")

        i = 0
        decision = ''
        while (i < len(out_dict[word]['sents'])) and (decision!='s')\
        and (decision!='q'):

            sent = out_dict[word]['sents'][i]
            if (sent not in examples[word]) and (sent not in counters[word]):
                print(sent)
                print('')
                decision = str(input("options : k,m,a,q,s,c"))
                if decision =='k':
                    try:
                        examples[word].append(sent) #by default adds examples
                        prev_learned[word] = eb_unk_in[word].copy()
                        del eb_unk_in[word] #remove lemma

                        i = 0
                        while i < len(eb_unk_m_in):

                            if eb_unk_m_in[list(eb_unk_m_in)[i]] == word:
                               del eb_unk_m_in[list(eb_unk_m_in)[i]]
                            else:
                                i +=1
                    except:
                        pass

                if decision =='m':
                    morph = str(input("which morph:"))
                    try:
                        del eb_unk_m_in[morph]
                        eb_unk_in[word].remove(morph) 
                    except:
                        pass
                if decision =='a':
                    try:
                        examples[word].append(sent)
                    except:
                        pass
                if decision=='c':
                    counters[word].append(sent)
                if decision =='q':
                    break
            i += 1

# %%
def how_to_add(word):
    """
    p = plain, add without conjurgating or changing
    c = conjugate as normal verb
    x = noun that adds x when plural
    s = noun that add s when plural
    iv = inner verb. There is a verb in the expression that should be 
        conjurgated
    """
    extras_morphs = []
    extras_morphs.append(word)
    
    
    gs = goslate.Goslate()

    default_conjugator = mlconjug3.Conjugator(language='fr')

    decision = str(input(word+"\nc\nx\ns\niv"))
    
    if decision == 'c':

        try:
            temp = []
            test_verb = default_conjugator.conjugate(word)
            all_conjugated_forms = test_verb.iterate()
            for item in all_conjugated_forms:
                if item not in temp:
                    temp.append(item[len(item)-1])
            extras_morphs.extend(list(set(temp)))
        except:
            pass
    elif decision == 'x':
        extras_morphs.append(lemma+'x')
    elif decision == 's':
        extras_morphs.append(lemma+'s')
    elif decision == 'iv':
        morph = str(input("which morph:"))
        

        temp = []
        test_verb = default_conjugator.conjugate(morph)
        all_conjugated_forms = test_verb.iterate()
        for item in all_conjugated_forms:
            if item not in temp:
                temp.append(item[len(item)-1])

        for variant in list(set(temp)):
            if variant is not None:
                new_word = word.replace(morph,variant)
                extras_morphs.append(new_word)

    return extras_morphs

# %%
"""
For eb_unk words: search through all articles, return 
sentences containing any words for unknown vocabulary. 

return dict object, key is lemma, then values are morphs found
and array of examples. 
"""

def find_unks(webpages,eb_unk_mo,prev_examples):
    
    output = {}
    for webpage in webpages:
        try:

            request=urllib.request.Request(webpage,None,headers) #The assembled request
            response = urllib.request.urlopen(request)
            data = response.read()
            contents = text_from_html(data)

            contents_array = sent_tokenize(contents)

            for line in contents_array:
                tokenized = word_tokenize(line, language='french')
                for word in tokenized:
                    if word.lower() in eb_unk_mo:

                        if word.lower() in prev_examples:
                            if line not in prev_examples[word.lower()]:
                                if word.lower() not in output:
                                    output[eb_unk_mo[word.lower()]] = {} #key will be lemma
                                    output[eb_unk_mo[word.lower()]]['morph'] = []
                                    output[eb_unk_mo[word.lower()]]['sents'] = []

                                output[eb_unk_mo[word.lower()]]['morph'].append(word.lower())
                                output[eb_unk_mo[word.lower()]]['sents'].append(line)

        except:
            pass
    return output

# %%
def filter_text(webpage,text=None,print_word_lvl=False):


    #try:
    if text is None:
        request=urllib.request.Request(webpage,None,headers) #The assembled request
        response = urllib.request.urlopen(request)
        data = response.read()
        contents = text_from_html(data)
    else:
        contents = webpage

    line_array = []
    percent_array = []
    contents_array = sent_tokenize(contents)

    disallowed_words = set()
    total_words = 0
    unknown_words = 0
    lines = []
    unknowns = []
    
    for line in contents_array:
        
        line_total = 0
        line_unks = 0
        tokenized = word_tokenize(line, language='french')

        unk_str = ""
        for word in tokenized:
            total_words +=1
            line_total +=1

            if not (bool(re.search("[0-9]", word)) or\
                    bool(re.search("[A-Z]", word)) or\
                    bool(re.search("[.,\/#!$%\^&\*;:{}=\-_`~()«»]", word)) or\
                    word.lower() in vocab['white_listed']):
                if not ((word.lower() in vocab['white_listed']) or (word.lower() in vocab['black_listed'])):
                    unk_str += '"'+word.lower()+'"'+", "

                disallowed_words.add(word.lower())
                unknown_words +=1
                line_unks +=1


        line_array.append(line)
        line_percent = (line_total-line_unks)/line_total
        percent_array.append(line_percent)

        if len(unk_str)>0:
            unk_str = unk_str[0:len(unk_str)-1]

        unknowns.append(unk_str)

    if print_word_lvl and total_words>0:
        print("word-level % known = "+str((1-(unknown_words/total_words))*100))

    return_pd = pd.DataFrame(list(zip(line_array,percent_array,unknowns)))
    return_pd.columns = ["line","line_percent","unk_words"]

    with open(path+'unknown_french_dad_list.txt',"w") as outfile:
        outfile.write(str(list(disallowed_words)))

    return return_pd
    
    #except:
    #    pass

# %% [markdown]
# ##Dad section

# %%
path = "/Users/elyebliss/Desktop/Vocabulary/language_learning/vocab_dfs/"
source_file = "french_dad.json"

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13427

# %%
            
##Journal en francais facile:
print("Checking Journal en francais facile")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://francaisfacile.rfi.fr/fr/podcasts/journal-en-fran%c3%a7ais-facile/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))


pages = []
for link in soup.find_all('a', href=True):
    if '/fr/podcasts/le-journal-en-fran%C3%A7ais-facile/' in str(link['href']):
        #print(str(link['href']))
        str_page = 'https://savoirs.rfi.fr/'+str(link['href'])
        #str_page = 'https://savoirs.rfi.fr/en/apprendre-enseigner/langue-francaise/journal-en-francais-facile-'+str(re.search(r"[0-9]{8}.*",str(link['href'])).group(0))
        if str_page not in pages:
            pages.append(str_page)

for page in pages:
    print(page)
# Out:
# Checking Journal en francais facile
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221125-foot-le-s%C3%A9n%C3%A9gal-se-relance-poutine-parle-aux-mamans-de-soldats-pourparlers-au-venezuela
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221124-prix-du-gaz-en-europe-foot-cameroun-0-suisse-1-l-arabe-du-futur
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221123-kiev-priv%C3%A9e-d-%C3%A9lectricit%C3%A9-cyberattaque-au-parlement-europ%C3%A9en-l-affaire-adrien-quatennens
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221122-france-les-magistrats-sont-en-gr%C3%A8ve-kherson-bombard%C3%A9e-par-les-russes-le-mondial-de-foot
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221121-mondial-de-foot-tortures-en-ukraine-chol%C3%A9ra-au-liban-ch%C3%B4mage-en-france
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221118-la-cor%C3%A9e-du-nord-tire-un-missile-la-cop27-black-ad-remporte-le-prix-d%C3%A9couvertes-rfi
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221117-600-prisonniers-lib%C3%A9r%C3%A9s-en-birmanie-l-ukraine-bombard%C3%A9e-que-fait-emmanuel-macron-%C3%A0-bangkok
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221116-la-fus%C3%A9e-artemis-d%C3%A9colle-lula-%C3%A0-la-cop27-un-missile-tombe-sur-la-pologne
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221115-la-russie-bombarde-l-ukraine-8-milliards-d-habitants-sur-terre-donald-trump-de-retour
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221114-joe-biden-et-xi-jinping-%C3%A0-bali-attentat-%C3%A0-istanbul-emmanuel-macron-veut-sanctionner-l-iran
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221111-l-ocean-viking-est-arriv%C3%A9-%C3%A0-toulon-la-cop-27-sadio-man%C3%A9-ira-au-qatar

# %%
with open(path+"text_input_web_dad_fr.txt","r") as infile:
    textfile = infile.read()
filtered_art = filter_text(textfile,text= True)
#display(filtered_art)

# %%
all_unks = set()

with open(path+'unknown_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [re.sub("^['|\"]|^\['|['|\"]$|'\]$|\[","",line.strip().lower()) for line in new_words] #update regex
    for word in new_words:
        all_unks.add(word)
len(all_unks)
# Out:
# 155

# %%
all_unks=list(all_unks)
unk_df = pd.DataFrame(all_unks)
unk_df.columns = ['word']
unk_df['status'] = pd.Series(['' for word in all_unks])

# %%
mitosheet.sheet(unk_df, analysis_to_replay="id-uzyggtxobg")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-uzyggtxobg", "analysisToReplay": null, "code": [], "stepSu…

# %%
add_ints = [0, 1, 6, 7, 8, 12, 16, 18, 22, 23, 24, 25, 28, 32, 33, 38, 40, 42, 48, 49, 54, 55, 58, 60, 62, 66, 68, 69, 72, 79, 80, 87, 91, 92, 94, 95, 96, 108, 107, 110, 111, 116, 120, 119, 122, 127, 130, 132, 133, 135, 136, 149, 152, 153]

# %%
for i in add_ints:
    # Set a cell value in status
    unk_df.at[i, 'status'] = 'k'

# %%
translations = []
for i in range(0,len(unk_df)):
    try:
        translations.append(ts.google(unk_df.word.iloc[i]))
    except:
        translations.append('')
unk_df['translations']=translations

# %%
mitosheet.sheet(unk_df, analysis_to_replay="id-ianxevwttg")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-ianxevwttg", "analysisToReplay": null, "code": [], "stepSu…

# %%
add_words = list(unk_df.word[unk_df['status']=='k'])
print(len(add_words))
for word in add_words:
    vocab['white_listed'].add(word)
# Out:
# 54

# %%
filtered_art = filter_text(textfile,text= True)

# %%
filtered_art['theme']=['' for line in filtered_art.line]
filtered_art = filtered_art[['theme','unk_words','line','line_percent']]
with open(path+'dad_choose_themes.xlsx','wb') as outfile:
    filtered_art.to_excel(outfile, encoding='utf-8',index=False)

# %%
with open(path+'dad_choose_themes.xlsx','rb') as infile:
    filtered_art = pd.read_excel(infile)

# %%
themes = set(filtered_art.theme[filtered_art['theme']!='NaN'])
output = pd.DataFrame(columns=['theme','line'])
for theme in themes:
    temp = filtered_art[['theme','line']][filtered_art['theme']==theme]
    output = pd.concat([output,temp])
with open(path+'dad_article.xlsx','wb') as outfile:
    output.to_excel(outfile, encoding='utf-8',index=False)

# %%
#write to .json formats
df = vocab
df['white_listed'] = list(df['white_listed'])
df['black_listed'] = list(df['black_listed'])
with open(path+source_file, "w") as outfile:
    json.dump(df,outfile)
print(len(vocab['white_listed']))
# Out:
# 13481

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13481

# %% [markdown]
# ##Filter for lessons

# %%
with open(path+"text_input_dad_fr.txt","r") as infile:
    textfile = infile.read()
filtered_art = filter_text(textfile,text= True)
#display(filtered_art)

# %%
with open(path+'unknown_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [re.sub("^['|\"]|^\['|['|\"]$|'\]$","",line.strip().lower()) for line in new_words] #update regex
#new_words
print(len(new_words))
known_manual = get_known(new_words)
# Out:
# 16
# cou
# Known =k
# 15 remaining
# poitrine
# Known =k
# 14 remaining
# rassuré
# Known =k
# 13 remaining
# vaste
# Known =k
# 12 remaining
# tatouages
# Known =k
# 11 remaining
# souvenirs
# Known =k
# 10 remaining
# maladie
# Known =k
# 9 remaining
# seins
# Known =k
# 8 remaining
# aliments
# Known =k
# 7 remaining
# réuni
# Known =k
# 6 remaining
# genoux
# Known =k
# 5 remaining
# bizarre
# Known =kk
# got 1
# 4 remaining
# colline
# Known =k
# 3 remaining
# –
# Known =kk
# got 2
# 2 remaining
# indigènes
# Known =k
# 1 remaining
# lors
# Known =k
# 0 remaining

# %%
print(len(known_manual))
for word in known_manual:
    vocab['white_listed'].add(word)
# Out:
# 2

# %%
#known_lines_only = list(set(list(filtered_art.knowns[filtered_art.knowns != "..."])))
#known_lines_only = sorted(known_lines_only,key=len)
filtered_art = filter_text(textfile,text= True)
known_lines_only = list(filtered_art.line[filtered_art['line_percent']==1.0])
known_lines_only = sorted(known_lines_only,key=len)

# %%
#export knowns: [filtered_art.knowns != "..."]
#known_list = list(filtered_art.knowns)
with open(path+"known_lines_dad_fr.txt","w") as outfile:
    for line in known_lines_only:
        outfile.write(line+"\n")

# %%
#write to .json formats
df = vocab
df['white_listed'] = list(df['white_listed'])
df['black_listed'] = list(df['black_listed'])
with open(path+source_file, "w") as outfile:
    json.dump(df,outfile)
print(len(vocab['white_listed']))
# Out:
# 13376

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13199

# %% [markdown]
# ##EB section

# %%
#read eb unknown files from .json formats
"""
Remaining vocab size = 2322
Total learned = 43
"""
with open(path+'eb_unk.json', "r") as infile:
    eb_unk = json.loads(infile.read())
print("Remaining vocab size = "+str(len(eb_unk)))

with open(path+'eb_unk_mo.json', "r") as infile:
    eb_unk_mo = json.loads(infile.read())

with open(path+'eb_learned.json', "r") as infile:
    eb_learned= json.loads(infile.read())
print("Total learned = "+str(len(eb_learned)))

with open(path+'eb_unk_examples.json', "r") as infile:
    eb_unk_examples= json.loads(infile.read())

with open(path+'eb_unk_counter_examples.json', "r") as infile:
    eb_unk_counter_examples= json.loads(infile.read())
# Out:
# Remaining vocab size = 2322
# Total learned = 43

# %%
"""
space = plain, add without conjurgating or changing
c = conjugate as normal verb
x = noun that adds x when plural
s = noun that add s when plural
iv = inner verb. There is a verb in the expression that should be 
    conjurgated
"""
with open(path+"fr_eb_extra.txt","r") as infile:
    extras_lemmas = infile.read().split('\n')

for lemma in extras_lemmas:
    extras_morphs = how_to_add(lemma)
    
    eb_unk[lemma] = extras_morphs
    for morph in extras_morphs:        
        if morph not in eb_unk_mo:
            eb_unk_mo[morph] = lemma

print("Remaining vocab size = "+str(len(eb_unk)))
# Out:
# riposte
# c
# x
# s
# ivs
# davantage
# c
# x
# s
# iv
# peiné
# c
# x
# s
# ivs
# briguer
# c
# x
# s
# ivc
# rien n’est joué
# c
# x
# s
# iv
# ne date pas d’hier
# c
# x
# s
# iv
# agacer
# c
# x
# s
# ivc
# autochtones
# c
# x
# s
# iv
# d'aplomb
# c
# x
# s
# iv
# âpre
# c
# x
# s
# ivs
# Remaining vocab size = 2332

# %% [markdown]
# Get larger list of pages to search

# %%
websites = set()
with open(path+'viewed_websites_fr.txt',"r") as infile:
    for line in infile.read().split('\n'):
        websites.add(line)
print(len(websites))
# Out:
# 152

# %%
pages = []

# %%
##France24
print("Checking France24")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.france24.com/fr/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))



for link in soup.find_all('a', href=True):
    str_ver = str(link['href'])
    
    #get regex such that links start with /fr/ and don't end
    #with /
    if bool(re.search('^\/fr\/.*',str_ver)) and (str_ver[len(str_ver)-1]!='/'):
        pages.append('https://www.france24.com'+str_ver)
# Out:
# Checking France24

# %%
##20minutes
print("Checking 20minutes")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.20minutes.fr/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

for link in soup.find_all('a', href=True):
    str_ver = str(link['href'])
    
    final_segment = str_ver.split('/')[len(str_ver.split('/'))-1]
    #articles have https:// at the beginning and a date in the last segment
    if ('https://www.20minutes.fr' in str_ver)\
    and bool(re.search('[0-9]',final_segment)):
        pages.append(str_ver)
# Out:
# Checking 20minutes

# %%
##TV5Monde
print("Checking TV5Monde")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.tv5monde.com/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

for link in soup.find_all('a', href=True):
    if '/info/' in str(link['href']):
        #print(str(link['href']))
        #str_page = 'https://savoirs.rfi.fr/'+str(link['href'])
        #str_page = 'https://savoirs.rfi.fr/en/apprendre-enseigner/langue-francaise/journal-en-francais-facile-'+str(re.search(r"[0-9]{8}.*",str(link['href'])).group(0))
        if str(link['href']) not in pages:
            pages.append(str(link['href']))
# Out:
# Checking TV5Monde

# %%
review_out(out,eb_learned,eb_unk,eb_unk_mo,eb_unk_examples,eb_unk_counter_examples)
# Out:
# Lemma: brassard
#
# Morph: ['brassard', 'brassard', 'brassard', 'brassard']
# Previous examples:
#  - Vu de Russie   Russie   Propagande   Mondial-2022       Contenus liés        L’invité du jour  Anna Colin-Lebedev : la propagande entretient "l’idée d’une guerre juste" auprès des Russes         Mondial-2022 : aucune sélection européenne ne portera le brassard anti-homophobie "One Love"         Le Débat de France 24  Émission spéciale : propagande et répression, chronique d'une Russie aux ordres              Précédentes émissions                18/11/2022 Villes ukrainiennes annexées : comment Vladimir Poutine réécrit l'Histoire                 11/11/2022 Les propagandistes russes inquiets après le retrait de Kherson                 04/11/2022 La Russie en quête d'une "idéologie" pour sa civilisation sur fond de guerre en Ukraine                 28/10/2022 La "bombe sale" en Ukraine : une "provocation" américaine, selon la propagande russe                                 La une         Replay            Replay                  Direct                 Actualités            Actualités                   Menu            Menu                  Page non trouvée      Le contenu auquel vous tentez d'accéder n'existe pas ou n'est plus disponible.
#  - Un brassard les a confondus Arrêtés mercredi et placés en garde à vue, les trois hommes ont été incarcérés vendredi soir par le juge des libertés et de la détention dans l’attente de leur jugement qui interviendra le 24 janvier, a indiqué le magistrat.
# New examples:
# « Début octobre, à l’occasion d’un des faits, un des individus a perdu un brassard de police et c’est ce qui a permis, grâce à l’analyse de ce brassard, de pouvoir identifier un premier individu, et ce sont ensuite les investigations subséquentes » qui ont permis d’identifier les deux autres, a expliqué le procureur.
#
# options : k,m,a,q,s,cs
# Lemma: chevet
#
# Morph: ['chevet']
# Previous examples:
#  - Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   Sport  L’ancien entraîneur de Reims Oscar Garcia annonce le décès de sa fille      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Coupe du monde 2022 Live score Basket Biathlon Cyclisme Football Formule 1 Mercato Rugby Tennis Sportune     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Coupe du monde 2022 Guerre en Ukraine Black Friday Inflation      Voir les tags précedents     Voir les tags suivants                    Accueil Sport   Ligue 1 : L’ancien entraîneur de Reims Oscar Garcia annonce le décès de sa fille   DRAME  Oscar Garcia a annoncé le décès de sa fille, au chevet de laquelle il se rendait fréquemment lorsqu’il entraînait Reims avant d’être renvoyé en octobre     N.S.
# New examples:
# Lemma: val
#
# Morph: ['val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', '
#     Jump to navigation                                             TV5 Monde    TV5MONDE Plus    TV    Vos rendez-vous    Guide des programmes    Revoir (replay)    Emissions    Réception TV    Direct TV      Info    Langue française    Afrique    Plus    Et aussi …    Voyage    Tivi5mondeplus    Nos applications mobiles    Flux RSS et widgets    Nous suivre sur les réseaux sociaux    Marchés publics          TV5MONDE à travers le monde     TV5MONDE Amérique Latine FR, EN, ES     TV5MONDE Asie/Pacifique FR, EN     TV5MONDE Etats-Unis EN     TV5MONDE Europe FR, EN, NL, DE, RO     TV5MONDE Maghreb-Orient FR, EN, AR             INFO     Formulaire de recherche   Rechercher          Menu        Menu principal Accueil  Videos  Afrique  Terriennes  Culture  Les journaux  En continu       Suivez-nous  Facebook  Twitter             Info     Collectivités, départements, régions : la France d'outre-mer La présidence d'Emmanuel Macron  Scandale du chlordécone aux Antilles : le parquet de Paris demande un non-lieu        Photo d'illustration d'une bananeraie.
#
# options : k,m,a,q,s,cc
# De son côté, la ministre belge Nicole De Moor a réclamé "aussi de la solidarité pour les États membres comme la Belgique qui font plus que leur part mais voient leurs capacités d'accueil saturées par les flux secondaires depuis des mois".
#
# options : k,m,a,q,s,ca
# Lemma: créneau
#
# Morph: ['créneau']
# New examples:
# Les États-Unis montent au créneau Lors d'un entretien la semaine dernière en marge du sommet du G20 à Bali, le président américain Joe Biden avait demandé à Xi Jinping de signifier " clairement " à la Corée du Nord de ne pas mener un nouvel essai nucléaire, comme Séoul et Washington lui en prêtent l'intention.
#
# options : k,m,a,q,s,ca
# Lemma: parquet
#
# Morph: ['parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet']
# Previous examples:
#  - Le parquet espagnol avait initialement requis deux ans de prison et dix millions d'euros d'amende à l'encontre de Neymar.
# New examples:
# DIRECT - Guerre en Ukraine : la Russie bombarde Kherson, au moins quinze civils tués            Au Québec, des femmes autochtones stérilisées de force            2 : 10   Guerre en Ukraine : le président russe Vladimir Poutine rencontre les mères de soldats mobilisés            Chine - Corée du Nord : Xi Jinping propose à Kim Jong Un de coopérer pour la paix dans le monde            Scandale du chlordécone aux Antilles : le parquet de Paris demande un non-lieu        Les JT - sidebar  Le 12'     En continu      19:53    Mondial-2022: Un doublé de Mbappé contre le Danemark envoie la France en 8e      19:51    Mondial: les Bleus visent déjà les huitièmes, Messi dos au mur      19:21    Acquitté par la justice internationale, Charles Blé Goudé est rentré en Côte d'Ivoire      19:05    Pakistan : l'ex-Premier ministre Imran Khan, récemment blessé par balle, veut continuer le combat      Tout le fil         Suivez-nous   Facebook   Twitter   Google +     Focus         Collection Reportages    [Collection Reportages] met en lumière des histoires, des documents, des portraits ou encore des enquêtes.
#
# options : k,m,a,q,s,cc
# Trois hommes ont été interpellés et incarcérés à Nantes pour une quinzaine de vols commis au domicile de personnes âgées, selon des informations du parquet délivrées vendredi.
#
# options : k,m,a,q,s,ca
# — SICCOLI PATRICK/SIPA        Deux enfants de six et neuf ans sont décédés lors de l’ incendie d’un immeuble à Onet-le-Château ( Aveyron ) ce samedi matin, a-t-on appris auprès du parquet de Rodez .
#
# options : k,m,a,q,s,ca
# Une enquête a été ouverte pour connaître les causes de l’incendie, a précisé le parquet.
#
# options : k,m,a,q,s,ca
# DIRECT - Guerre en Ukraine : la Russie bombarde Kherson, au moins quinze civils tués            Au Québec, des femmes autochtones stérilisées de force            2 : 10   Guerre en Ukraine : le président russe Vladimir Poutine rencontre les mères de soldats mobilisés            Chine - Corée du Nord : Xi Jinping propose à Kim Jong Un de coopérer pour la paix dans le monde            Scandale du chlordécone aux Antilles : le parquet de Paris demande un non-lieu        Les JT - sidebar  Le 12'     En continu      20:04    Charles Blé Goudé, acquitté par la justice internationale, est rentré en Côte d'Ivoire      19:53    Mondial-2022: Un doublé de Mbappé contre le Danemark envoie la France en 8e      19:51    Mondial: les Bleus visent déjà les huitièmes, Messi dos au mur      19:21    Acquitté par la justice internationale, Charles Blé Goudé est rentré en Côte d'Ivoire      Tout le fil         Suivez-nous   Facebook   Twitter   Google +     Focus         Collection Reportages    [Collection Reportages] met en lumière des histoires, des documents, des portraits ou encore des enquêtes.
#
# options : k,m,a,q,s,cc
# ©  Pierre René-Worms, France 24         Texte par :  FRANCE 24  Suivre   |   Vidéo par :  FRANCE 2     4 mn    Le parquet national financier a confirmé, jeudi, l'ouverture de deux informations judiciaires en octobre pour "tenue non-conforme des comptes de campagne" et "favoritisme et recel de favoritisme" de la part de cabinets de conseil sur les deux campagnes électorales de 2017 et 2022 du président de la République.
#
# options : k,m,a,q,s,ca
# Le parquet national financier a annoncé, jeudi 24 novembre, avoir ouvert fin octobre deux informations judiciaires portant sur l'intervention des cabinets de conseil dans les campagnes électorales de 2017 et 2022 .
#
# options : k,m,a,q,s,ca
# "Il appartient à la justice de conduire ces investigations en toute indépendance", a commenté l'Élysée jeudi soir, après avoir "pris connaissance de la communication" du parquet national financier.
#
# options : k,m,a,q,s,ca
# Après un article du journal Le Parisien intitulé "Affaire McKinsey : Emmanuel Macron visé par une enquête pour financement illégal de campagne" , le parquet national financier (PNF) a publié un communiqué pour "clarifier la situation de différentes procédures pénales" initiées après le rapport du Sénat et divers plaintes et signalements.
#
# options : k,m,a,q,s,ca
# Le parquet y précise que "suite à plusieurs signalements et plaintes d'élus et de particuliers, une information judiciaire a été ouverte le 20 octobre 2022, notamment des chefs de tenue non conforme de comptes de campagne et minoration d'éléments comptables dans un compte de campagne, portant sur les conditions d'intervention de cabinets de conseils dans les campagnes électorales de 2017 et 2022".
#
# options : k,m,a,q,s,ca
# Macron pourrait être convoqué à la fin de son second mandat Le chef de l'État, dont le nom ne figure pas dans le communiqué du parquet, est protégé par son immunité pénale, prévue à l'article 67 de la Constitution.
#
# options : k,m,a,q,s,ca
# Une opération de police était en cours ce samedi sur le territoire national pour retrouver une fillette de six mois, confiée à l’ aide sociale à l’enfance et enlevée par ses parents vendredi au CHU de Saint-Etienne , a-t-on appris auprès du parquet de la ville.
#
# options : k,m,a,q,s,ca
# Pas d'alerte enlèvement L’alerte enlèvement n’a pas été déclenchée car le parquet stéphanois a considéré que les critères, notamment celui de la mise en danger de l’enfant, « n’étaient pas remplis ».
#
# options : k,m,a,q,s,ca
# Le parquet de Limoges a ouvert vendredi une enquête pour « vol avec violences ayant entraîné la mort », a-t-on indiqué de même source.
#
# options : k,m,a,q,s,ca
# Trois individus ont été arrêtés après la violente agression d’un couple de Britanniques en août 2022 dans le Lot-et-Garonne , ont indiqué vendredi le parquet d’Agen et la gendarmerie dans un communiqué.
#
# options : k,m,a,q,s,cs
# Lemma: tasser
#
# Morph: ['tasser']
# New examples:
# Grâce aux barnums, ces bistrots voyaient régulièrement des dizaines de clients se tasser sous les bâches et ce, même quand la météo était immonde.
#
# options : k,m,a,q,s,ca
# Lemma: enchevêtrement
#
# Morph: ['enchevêtrement']
# New examples:
# La rue Saint-Michel, célèbre rue de la Soif, est plus aérée, tout comme la place Sainte-Anne, où l’enchevêtrement des tentes et surtout des bâches étouffait le patrimoine.
#
# options : k,m,a,q,s,ca
# Lemma: péniche
#
# Morph: ['péniche']
# New examples:
# Rennes Rennes : Pourquoi la péniche bar des Grands Gamins a dû fermer ses portes Rennes Rennes : Voici le premier palmarès des meilleurs bars à bières de la capitale bretonne   Rennes Bretagne Bar Apero Hiver Froid Pluie Fête Jeunes Etudiant Société    Une faute ?
# options : k,m,a,q,s,ca
# Lemma: déjouer
#
# Morph: ['déjouer']
# New examples:
# Cette récompense vise à féliciter ceux qui « ont réussi » et su « déjouer les pièges tendus par des féministes acharnées ».
#
# options : k,m,a,q,s,ca
# Lemma: pantin
#
# Morph: ['pantin']
# New examples:
# 07/10/22 |                             #MeToo  Sexisme : Infirmières et femmes médecins dénoncent le milieu médical              09/09/22 |                             SANS TABOU  Pantin : Au Wetoo Festival, la vulve racontée aux ados         Plus  d’actu      Précédent    1 sur 2     Suivant                                           Retourner en haut de la page        Annonces Légales   Annonces légales  Allier  Alpes Maritimes  Bas Rhin  Bouches du Rhône  Côtes d'Armor  Finistère  Haut Rhin  Hauts de Seine  Loire  Loire Atlantique  Loiret  Maine et Loire  Marne  Paris  Seine Maritime  Val d'Oise  Val de Marne  Var  Vaucluse  Yvelines      Services   Distribution  Horoscope  Horoscope chinois  Conjugaison  Recette de cuisine  Résultats des élections  Maison  Le Journal des Seniors  Bébés et Mamans  Infolocale  Sportune   Codes promo   Codes promo  Code promo AliExpress  Code promo Carrefour  Code promo Dell  Code promo Vistaprint  Code promo Black Friday     20 Minutes   Recrutement  La 21 e Minute  20 Minutes Média  Panel des lecteurs  20 Minutes Livres  Charte   Jeux   Jeux gratuits  Mots fléchés  Solitaire  Puzzle  Mots croisés  Sudoku      Réseaux sociaux        Facebook  2,9M         Twitter  2.4M         Instagram  320K         Youtube  27K         Dailymotion  9,8K         Flipboard  114K      Newsletters  Votre résumé de l'actualité à lire tous les matins     Applications mobiles  Découvrez nos applications             La politique RSE de 20 Minutes est certifiée par le label Silver d’Ecovadis        Plan du site  Notre charte  Journal PDF  Archives  Publicité  Mentions légales  CGU  Protection des données personnelles  Gestion des cookies  Nous contacter    Choix de consentement  © Copyright  20 Minutes  - La fréquentation de 20 Minutes est certifiée par l’ACPM
#
# options : k,m,a,q,s,cc
# Lemma: dépouiller
#
# Morph: ['dépouiller']
# Previous examples:
#  - 80% des bulletins ont été dépouillés ce soir et selon les premiers résultats, le conservateur Anzé Logar fait la course en tête.
# New examples:
# Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   Faits divers  Trois faux policiers accusés d’avoir dépouillé des personnes âgées à Nantes      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Faits divers  Paris Lyon Marseille Nantes Toulouse Rennes Strasbourg Montpellier Nice Lille Bordeaux     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Coupe du monde 2022 Guerre en Ukraine Black Friday Inflation      Voir les tags précedents     Voir les tags suivants                    Accueil Faits divers   Nantes : Trois faux policiers interpellés pour des vols commis chez des personnes âgées   ARNAQUE  Les interpellés sont en état de récidive     20 Minutes avec AFP    Publié le 26/11/22 à 11h39 — Mis à jour le 26/11/22 à 13h32       23    commentaires    1   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Les trois hommes, dont un père et son fils, se seraient fait passer pour des policiers pour dépouiller des personnes âgées.
#
# options : k,m,a,q,s,cc
# Lemma: poignard
#
# Morph: ['poignard']
# New examples:
# © France 24     Parmi les 5 000 objets découverts : un lit en bois plaqué or, un char, ou encore un poignard.
#
# options : k,m,a,q,s,ca
# Lemma: aboutissement
#
# Morph: ['aboutissement']
# New examples:
# Le déchiffrement de l'égyptien hiéroglyphique a été l’aboutissement d'une quête d'une durée de plusieurs siècles : "C’est passé par les Arabes, puis c’est arrivé chez nous à la Renaissance”, poursuit Dominique Farout.
#
# options : k,m,a,q,s,ck
# Lemma: déchiffrer
#
# Morph: ['déchiffrer']
# New examples:
# Vingt-trois ans après l’expédition, Jean-François Champollion révèle au monde la clé pour déchiffrer les hiéroglyphes, langue tombée dans l’oubli depuis quinze siècles.
#
# options : k,m,a,q,s,ck
# Lemma: rayonnement
#
# Morph: ['rayonnement']
# New examples:
# L’Égypte mise en effet sur Toutânkhamon pour son rayonnement culturel.
#
# options : k,m,a,q,s,ca
# Lemma: gammée
#
# Morph: ['gammée', 'gammée']
# New examples:
# © Antonio Moreira, AFP         Texte par :  FRANCE 24  Suivre     4 mn    Le visage couvert et une croix gammée sur ses vêtements, un jeune brésilien de 16 ans a tué au moins trois personnes, vendredi, et fait 11 blessés dans deux établissements scolaires de l'État d'Espirito Santo, dans le sud-est du Brésil.
#
# options : k,m,a,q,s,ca
# Le visage couvert et une croix gammée sur ses vêtements de camouflage, l'assaillant s'est introduit dans l'école Primo Bitti, une école primaire et secondaire publique qu'il avait quittée en juin, selon les enquêteurs.
#
# options : k,m,a,q,s,cc
# Lemma: sillage
#
# Morph: ['sillage']
# New examples:
# Les images de vidéosurveillance diffusées par les médias montrent le jeune homme entrant dans l'école avec une arme à la main, tandis que plusieurs personnes fuient dans son sillage.
#
# options : k,m,a,q,s,ca
# Lemma: biais
#
# Morph: ['biais', 'biais']
# New examples:
# Soyez forts contre les fake news OMF Oh My Fake sur Snapchat Discover, c’est le programme de 20 Minutes qui vous rend fort contre les fake news , et plus largement vous invite à comprendre les ressorts et biais psychologiques qui incitent au partage et à la viralité.
#
# options : k,m,a,q,s,ca
# Nous ne pouvons apporter des changements durables que par le biais des institutions ».
#
# options : k,m,a,q,s,ca
# Lemma: succomber
#
# Morph: ['succomber']
# New examples:
# – peuvent y succomber.
#
# options : k,m,a,q,s,cc
# Lemma: rédaction
#
# Morph: ['rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction', 'rédaction']
# New examples:
# Français   English   Español   عربي                                 Naviguer hors connexion                 S'abonner aux newsletters                  Gérer mes consentements                   Emissions   Reportages                  France   Afrique   Moyen-Orient   Europe   Amériques   Asie-Pacifique          Accéder au contenu principal       France 24 - Infos, news & actualités - L'information internationale en direct                                                                                                      /  Contenus sponsorisés       Contenu sponsorisé   Proposé par       La rédaction n’a pas contribué à la réalisation de cet article.
#
# options : k,m,a,q,s,ca
# L’appareil s’occupe de tout     20 Minutes Guide d'achat    Publié le 26/11/22 à 18h02       0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Black Friday Cdiscount : Roborock S7 Aspirateur Robot blanc à 389,99€  — DR     La rédaction de 20 Minutes n'a pas participé à la réalisation de cet article.
#
# options : k,m,a,q,s,cc
# La rédaction n’a pas participé à sa réalisation.
#
# options : k,m,a,q,s,ca
# Depuis le début du projet, en mars 2016, nous avons interrogé des milliers de personnes âgées entre 18 et 30 ans, sur des thématiques définies par des journalistes de la rédaction ou suggérées par les jeunes.
# options : k,m,a,q,s,ca
# • Accédez à nos articles, reportages, émissions, vidéos  • Recevez des notifications d’alertes infos  • Suivez les Tweets des journalistes de la rédaction de France 24  • Partagez sur les réseaux sociaux les articles et vidéos qui vous ont marqués     Téléchargez la dernière version de l'application et bénéficiez des dernières évolutions ainsi que des améliorations réalisées grâce à vos remarques, pour naviguer facilement vers les contenus exclusifs préparés par les équipes de France 24.
#
# options : k,m,a,q,s,cc
# L’enseigne propose dans ses rayons de nombreux produits à prix attractif toute l’année     20 Minutes Guide d'achat    Publié le 22/11/22 à 18h18       0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          ELECTRO DEPOT : la sélection cadeaux du « Comme D’hab Friday » — DR     La rédaction de 20 Minutes n'a pas participé à la réalisation de cet article.
#
# options : k,m,a,q,s,cc
# 20 Minutes Guide d'achat    Publié le 26/11/22 à 19h50       0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Résultats Loto FDJ : les résultats du tirage du samedi 26 novembre — DR     La rédaction de 20 Minutes n'a pas participé à la réalisation de cet article.
#
# options : k,m,a,q,s,cc
# À l’occasion des célèbres soldes, Amazon baisse les prix sur de nombreux articles de la marque     20 Minutes Guide d'achat    Publié le 26/11/22 à 16h02       0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Black Friday Amazon : L’électroménager Philips en promo — DR     La rédaction de 20 Minutes n'a pas participé à la réalisation de cet article.
#
# options : k,m,a,q,s,cc
# Qu’il s’agisse d’un choix de titre, d’un sujet qui, selon vous, n’est pas assez mis en avant, du fonctionnement de la rédaction, de la logique de nos choix… Tous les messages que vous enverrez via le formulaire ci-dessous seront lus et traités, afin de vous répondre de la façon la plus claire et la plus transparente possible.
#
# options : k,m,a,q,s,ca
# « Depuis sa création il y a près de vingt ans, 20 Minutes a mis l’accent sur la création, avec ses lectrices et lecteurs, d’une véritable communauté, souligne Armelle Le Goff, directrice de la rédaction.
#
# options : k,m,a,q,s,ca
# Une communauté de lecteurs, cela implique des échanges quasi quotidiens, mais aussi une certaine transparence dans nos modes de fonctionnement et notre façon de construire l’information à la rédaction.
#
# options : k,m,a,q,s,cc
# Vous pourrez profiter de réductions jusqu’à -50% jusqu’au 28 novembre     20 Minutes Guide d'achat    Publié le 25/11/22 à 15h32       0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Black Friday Conforama : jusqu’à -50% de remise sur une sélection de produits jusqu’au 28 novembre 2022 — DR     La rédaction de 20 Minutes n'a pas participé à la réalisation de cet article.
#
# options : k,m,a,q,s,cc
# La Charte de 20 Minutes est donc un code éthique pour notre communauté qui dépasse la seule activité de la rédaction, sa responsabilité morale ou encore la traditionnelle déontologie professionnelle des journalistes.
#
# options : k,m,a,q,s,ca
# Pour la rédaction du journal, ce code éthique s’impose à tous les journalistes, au personnel associé à la rédaction et à ses cadres dirigeants.
#
# options : k,m,a,q,s,ca
# A cette fin notamment, la rédaction recourt à certains outils de l’écriture inclusive.
#
# options : k,m,a,q,s,ca
# 1.7 Les contenus des annonces commerciales, textes ou publicités classiques, émanant d’organisations politiques, syndicales ou assimilées, ou religieuses, doivent être systématiquement soumis à l’approbation du directeur de la publication ou de la rédaction par délégation de responsabilité, afin de certifier qu’ils sont en accord avec la politique éditoriale de 20 Minutes .
#
# options : k,m,a,q,s,ca
# Le directeur de la rédaction, le rédacteur en chef, et tous les autres éditeurs, qu’ils soient journalistes ou de l’encadrement, œuvrent dans le cadre et sous couvert de cette responsabilité.
#
# options : k,m,a,q,s,ca
# D’une façon générale, les membres de la rédaction ne doivent pas accepter les commissions, les soutiens financiers ou les doubles fonctions qui pourraient créer des conflits d’intérêts avec leurs tâches éditoriales.
#
# options : k,m,a,q,s,ca
# Exceptionnellement, des collaborations extérieures rémunérées sont envisageables avec l’autorisation de la direction de la rédaction.
#
# options : k,m,a,q,s,ca
# 2.6 La participation à des colloques, conférences, jurys, réunions et débats publics, qu’ils soient organisés par des organismes publics ou privés, doit faire l’objet d’un accord de la direction de la rédaction.
#
# options : k,m,a,q,s,ca
# Les journalistes de 20 Minutes peuvent en revanche être sollicités par la direction de l’entreprise ou de la rédaction pour participer à des manifestations dans l’intérêt de l’entreprise, de la marque, dans un but de notoriété, ou dans le cadre d’une collaboration rédactionnelle avec des médias ou des entreprises partenaires.
#
# options : k,m,a,q,s,ca
# La direction de la rédaction prend en charge avec des journalistes salariés, ou en faisant appel à des contributeurs extérieurs, la production de contenus rédactionnels contextuels.
#
# options : k,m,a,q,s,ca
# ...
#
# Morph: ['poussé', 'poussé']
# New examples:
# Alors, quelle n’a pas été sa surprise quand, le lendemain, le leader de U2 a poussé la porte de la librairie comme si de rien n’était !
#
# options : k,m,a,q,s,ck
# Lemma: enfoui
#
# Morph: ['enfoui']
# Previous examples:
#  - Ils ont mis à jour un panneau enfoui à moitié dans le sable, environ cinq mètres de côté.
# New examples:
# People Bono révèle un secret familial enfoui depuis plus de 20 ans   People Bono Noël Chanteur Livres U2 Vidéo    Une faute ?
#
# options : k,m,a,q,s,ca
# Lemma: usé
#
# Morph: ['usé']
# New examples:
# Publicité         Lire la suite                 L'Argentine a usé de son joker en perdant contre l'Arabie saoudite d'Hervé Renard .
#
# options : k,m,a,q,s,ca
# Lemma: hareng
#
# Morph: ['hareng']
# New examples:
# Depuis 1977, cet accord, renouvelable annuellement, porte sur des quotas de prises sur plusieurs espèces (notamment du cabillaud, de l’églefin, du merlan et du hareng) en mer des Barents pour les marins férigiens et dans les eaux au large des îles Féroé pour les Russes.
#
# options : k,m,a,q,s,ca
# Lemma: obus
#
# Morph: ['obus']
# New examples:
# Sa maison ayant été largement détruite par les bombardements, Serguiï Khmil travaille dur pour convertir sa cuisine d’été en logement hivernal de fortune, désormais rempli de couvertures, de caisses de munitions et d’un fourneau assemblé à partir de douilles d’obus russes.
#
# options : k,m,a,q,s,ck
# Lemma: pépé
#
# Morph: ['pépé']
# New examples:
# A compter de ce vendredi et jusqu’au 25 novembre, les particuliers ont en effet la possibilité de venir déposer le vieux fusil hérité de pépé dont ils veulent se débarrasser.
#
# options : k,m,a,q,s,ca
# Lemma: craie
#
# Morph: ['craie']
# New examples:
# Pendant qu’un « responsable armes et munitions » de la police nationale vérifie qu’elles sont bien déchargées et relèvent les numéros de série en les faisant apparaître grâce à une craie, il explique qu’il « préfère que ce soit l’Etat plutôt qu’un armurier qui s’occupe de ça ».
#
# options : k,m,a,q,s,ca
# Lemma: divisionnaire
#
# Morph: ['divisionnaire']
# New examples:
# Enlever de la circulation, éviter les vols « En tout cas, tous ceux qui seront apportés au cours de cette semaine, ce sera autant de moins en circulation dans le pays », plaide le commandant divisionnaire Lilian Clément, qui supervise l’opération pour la police nationale à Toulouse.
#
# options : k,m,a,q,s,ck
# Lemma: trousse
#
# Morph: ['trousse', 'trousse', 'trousse']
# New examples:
# SANTE  Testé par « 20 Minutes », le nouvel hydropulseur nomade de Panasonic est-il indispensable à emporter avec soi dans une trousse de toilette     Christophe Séfrin     Publié le 26/11/22 à 11h17       5    commentaires    1   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          L'hydropulseur nomade Panasonic EW-DJ4B-G503 grandit-il des dents bien blanches?
#
# options : k,m,a,q,s,cc
# 240 grammes dans la trousse de toilette Face aux modèles standards et sédentaires (parfois un peu encombrants), branchés sur secteur dans la salle de bains, de plus en plus de modèles nomades comme le nouveau EW-DJ4B-G503 de Panasonic veulent nous accompagner partout.
#
# options : k,m,a,q,s,ca
# - Panasonic Fonctionnant sur batterie, avec un temps de recharge d’une heure, le petit appareil (15,4 cm de hauteur, pour 52 mm de diamètre) n’alourdira que peu votre trousse de toilette avec ses 240 grammes.
#
# options : k,m,a,q,s,ca
# Lemma: parfaire
#
# Morph: ['parfaire', 'parfaire']
# New examples:
# En envoyant entre les dents un puissant et fin jet d’eau, ce type d’appareil permet de parfaire le travail, mais aussi de lutter contre la plaque dentaire.
#
# options : k,m,a,q,s,ck
# Lemma: interstice
#
# Morph: ['interstice']
# New examples:
# Plus encore, en nettoyant les poches parodontales (l’interstice entre la dent et la gencive), l’hydropulseur contribue à une meilleure hygiène bucco-dentaire et à la réduction de la plaque dentaire.
#
# options : k,m,a,q,s,ck
# Lemma: asperger
#
# Morph: ['asperger']
# New examples:
# A défaut, on risque d’asperger de l’eau un peu partout autour de soi (vécu !).
#
# options : k,m,a,q,s,ca
# Lemma: emballage
#
# Morph: ['emballage']
# New examples:
# On peut regretter que Panasonic ne fournisse qu’une canule dans l’emballage, alors que plusieurs membres de la famille peuvent être appelés à l’utiliser son hydropulseur.
#
# options : k,m,a,q,s,ca
# Lemma: pommeau
#
# Morph: ['pommeau']
# New examples:
# New examples:
# En Amérique latine, la tauromachie s'essouffle De l'autre côté de l'Atlantique, la corrida n'a plus la cote depuis un moment.
#
# options : k,m,a,q,s,ca
# Lemma: fervent
#
# Morph: ['fervent']
# New examples:
# Mais dans ce pays d'Amérique du Sud aussi, la situation pourrait rapidement évoluer, le nouveau président Gustavo Petro se présentant comme fervent opposant à la tauromachie.
#
# options : k,m,a,q,s,ck
# Lemma: reléguer
#
# Morph: ['reléguer']
# New examples:
# Au cri de "corrida basta", les manifestants réunis en arc de cercle sur la Place du Châtelet à Paris, symbolisant une arène, ont demandé de "reléguer les arènes taurines aux oubliettes de l'histoire".
#
# options : k,m,a,q,s,ck
# Lemma: crac
#
# Morph: ['crac']
# New examples:
# Selon Marie-Anne Leneveu, du Comité radical anti-corrida (CRAC), "ce n'est pas une minorité qui doit imposer son avis à la majorité".
#
# options : k,m,a,q,s,cc
# Lemma: lucarne
#
# Morph: ['lucarne']
# New examples:
# En cinq ans et demi à Arsenal, le canonnier français déroule sa palette : subtiles déviations, coups de casque et gros pétards en lucarne, tout y passe.
#
# options : k,m,a,q,s,ca
# Lemma: bourre
#
# Morph: ['bourre']
# New examples:
# "Je l'inviterai sur un circuit de kart et on se tirera la bourre au kart, voilà!
#
# options : k,m,a,q,s,ca
# Lemma: épave
#
# Morph: ['épave']
# New examples:
# Latest Defence Intelligence update on the situation in Ukraine - 26 November 2022  Find out more about the UK government's response: https://t.co/htZ2ZsfvmF 🇺🇦 #StandWithUkraine 🇺🇦 pic.twitter.com/RZ6by8tN5p — Ministry of Defence 🇬🇧 (@DefenceHQ) November 26, 2022        Des images open source montreraient ainsi l’épave d’un missile de croisière tiré sur l’Ukraine conçu dans les années 1980 comme un système d'acheminement d'armes nucléaires, selon les services de renseignement britanniques.
#
# options : k,m,a,q,s,cc
# Lemma: épuisement
#
# Morph: ['épuisement']
# New examples:
# "Cette improvisation met en évidence le niveau d’épuisement du stock russe de missiles à longue portée ", assurent les experts britanniques qui soulignent la faible précision de ce type de projectiles.
#
# options : k,m,a,q,s,ck
# Lemma: rallier
#
# Morph: ['rallier']
# New examples:
# Vladimir Poutine ne parvient pas à rallier toute la population derrière lui, et à trop chercher à homogénéiser un pays, on risque au contraire d'en exacerber les différences."
#
# options : k,m,a,q,s,ck
# Lemma: attiser
#
# Morph: ['attiser']
# New examples:
# De votre enfance à aujourd’hui, en passant par Pokémon, Olive et Tom ou bien encore Naruto, les animes continuent à attiser les plus jeunes.
#
# options : k,m,a,q,s,ca
# Lemma: charrier
#
# Morph: ['charrier', 'charrier']
# Previous examples:
Par :  Alexandre CAPRON            13:51        SPORTS WEEK-END            14:00        LE JOURNAL            14:15                L'Entretien  Par :  Valériane GAUTHIER,  Marc PERELMAN,  Armelle CHARRIER,  Stéphanie ANTOINE,  Virginie HERZ,  Gauthier RYBINSKI            14:30        LE JOURNAL            14:45                Le gros mot de l'éco  Par :  MYRIAM MASCARELLO            15:00        LE JOURNAL            15:10                Légendes urbaines  Par :  Juliette FIEVET            15:30        LE JOURNAL            15:40                Ici l'Europe  Par :  Caroline DE CAMARET            16:00        LE JOURNAL            16:15                Demain à la une  Par :  Aziza NAIT SIBAHA            16:30        LE JOURNAL            16:45                Demain à la une  Par :  Aziza NAIT SIBAHA            17:00        LE JOURNAL            17:10                Billet retour  Par :  Vincent ROUX            17:30        LE JOURNAL            17:40                À l'Affiche !
#
# options : k,m,a,q,s,cc

# %%
pages = list(set(pages))
len(pages)
#add in set_difference line here
# Out:
# 148

# %%
with open(path+'viewed_websites_fr.txt',"w") as outfile:
    for line in websites:
        outfile.write(line+'\n')

# %%
out = find_unks(pages,eb_unk_mo,eb_unk_examples)

# %%
#write to eb unknown files to .json formats
"""
Remaining vocab size = 2278
Total learned = 87
"""
with open(path+'eb_unk.json', "w") as outfile:
    json.dump(eb_unk,outfile)
print("Remaining vocab size = "+str(len(eb_unk)))

with open(path+'eb_unk_mo.json', "w") as outfile:
    json.dump(eb_unk_mo,outfile)

with open(path+'eb_learned.json', "w") as outfile:
    json.dump(eb_learned,outfile)
print("Total learned = "+str(len(eb_learned)))

with open(path+'eb_unk_examples.json', "w") as outfile:
    json.dump(eb_unk_examples,outfile)

with open(path+'eb_unk_counter_examples.json', "w") as outfile:
    json.dump(eb_unk_counter_examples,outfile)
# Out:
# Remaining vocab size = 2278
# Total learned = 87

# %% [markdown]
# ### Code no longer in use

# %%
def return_line_percents(webpage):
    request=urllib.request.Request(webpage,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read()
    contents = text_from_html(data)

    known_array = []
    unk_array = []
    contents_array = sent_tokenize(contents)

    lines = []

    for line in contents_array:
        tokenized = word_tokenize(line, language='french')

        line_total = 0
        line_unks = 0
        for word in tokenized:

            line_total +=1

            if not (bool(re.search("[0-9]", word)) or\
                    bool(re.search("[A-Z]", word)) or\
                    bool(re.search("[.,\/#!$%\^&\*;:{}=\-_`~()«»]", word)) or\
                    word.lower() in vocab['white_listed']):

                    line_unks +=1

            lines.append(100*(line_total-line_unks)/line_total)
    return(lines)

# %%
if (start is not None) and (stop is not None):
    contents_array=contents_array[max(start,0):min(stop,len(contents_array))]

with open(path+'unknown_french_dad_list.txt',"w") as outfile:
    outfile.write(str(list(disallowed_words)))

# %%
##add in extras
with open("/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/fr_eb_extra.txt","r") as infile:
    extras_lemmas = infile.read().split('\n')

gs = goslate.Goslate()

default_conjugator = mlconjug3.Conjugator(language='fr')


for lemma in extras_lemmas:
    
    decision = how_to_add(lemma)
    
    if lemma not in eb_unk:
        eb_unk[lemma] = []
        
    extras_morphs = []
    extras_morphs.append(lemma)
    try:
        #if it's an infinitive, add all conjurgations
        test_verb = default_conjugator.conjugate(lemma)
        all_conjugated_forms = test_verb.iterate()
        for item in all_conjugated_forms:
            if item not in extras_morphs:
                extras_morphs.append(item[len(item)-1])
        extras_morphs = list(set(extras_morphs))
    except:
        
        #if not an expression:
        if len(lemma.split(' '))==1:
            #add plural nouns
            if lemma[len(lemma)-1]=='u':
                extras_morphs.append(lemma+'x')
            else:
                extras_morphs.append(lemma+'s')

    eb_unk[lemma] = extras_morphs
    for morph in extras_morphs:        
        if morph not in eb_unk_mo:
            eb_unk_mo[morph] = lemma

print("Remaining vocab size = "+str(len(eb_unk)))
# Out:
# Remaining vocab size = 2327

# %%
#Upload from download
with open(path+'known_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [line.replace('"',"").strip().lower() for line in new_words]
    print("daily catch in word count:")
    print(len(new_words))
    
    for line in new_words:   
        vocab['white_listed'].add(line.replace('"',"").strip().lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 #Upload from download
# ----> 2 with open(path+'known_french_dad_list.txt',"r") as input_file:
#       3     new_words = input_file.read()
#       4     new_words = re.sub('\n',"",new_words)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/known_french_dad_list.txt'

# %%
"""
to do:

"""

# %%
##INPUT-OUTPUT
#vocab list:
with open("/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/dad_whitelisted.csv","r") as infile:
    whitelisted_lemmas = infile.read()


##VARIABLES
vocab_all = set()
gs = goslate.Goslate()

default_conjugator = mlconjug3.Conjugator(language='fr')


for line in whitelisted_lemmas.split('\n'):
    if len(line) > 0:
        #print(line)
        vocab = line.lower().strip()
        vocab_all.add(vocab)
        try:
            #if it's an infinitive, add all conjurgations
            test_verb = default_conjugator.conjugate(vocab)
            all_conjugated_forms = test_verb.iterate()
            for item in all_conjugated_forms:
                
                vocab_all.add(item[len(item)-1])
                
            
        except:
            #might be a noun, add plural
            vocab_all.add(add_noun(vocab))
#len(whitelisted_lemmas.split('\n'))            
#pp.pprint(vocab_all)

# %%
vocab = {}
vocab['white_listed'] = list(vocab_all)
vocab['black_listed'] = []

# %%
#used for creating eb data

with open(path+'eb_unk_lemmas.csv','r') as infile:
    eb_unk_lemmas = pd.read_csv(infile)
with open(path+'eb_unk_morph.csv','r') as infile:
    eb_unk_morph = pd.read_csv(infile)
    
eb_unk = {}
for word in eb_unk_lemmas.lemme:
    eb_unk[word] = []

    for index, row in eb_unk_morph.iterrows():
        if row.lemme == word:
            eb_unk[word].append(row.ortho)
eb_unk_mo = {}
for lemma in eb_unk.keys():
    for morph in eb_unk[lemma]:
        eb_unk_mo[morph] = lemma

# %%
eb_learned = {}
eb_unk_examples = {}
for word in eb_unk.keys():
    eb_unk_examples[word] = []

# %%
#restore to backups
eb_learned = eb_learned_backup
eb_unk = eb_unk_backup
eb_unk_mo = eb_unk_mo_backup
eb_unk_examples = eb_unk_examples
