# %%
"""
Get articles/texts, and filter only sentences with white-listed vocab OR named entities.

Contents:
-load packages
-create helper functions
-data intialization from csv file of words &
 extend vocab set
-build data structure to house info moving forward
-write to .json formats
-read from existing .json formats
-get white-listed of words and inflections
-scrape journale en francais facile
"""

# %%
import bs4, requests, sys, codecs, urllib.request, re
from bs4 import SoupStrainer
from bs4.element import Comment
import random
import string
import json
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import mlconjug3
import sklearn
import goslate
from nltk.tokenize import word_tokenize, sent_tokenize
import pprint
pp = pprint.PrettyPrinter()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 0)
import mitosheet
import translators as ts

# %%
def add_noun(add_word):

    if add_word[len(add_word)-1] != 's' and add_word[len(add_word)-1] != 'x':

        out_word = add_word + 's'

        return out_word
    else:
        return add_word

# %%
##METHODS

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = bs4.BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)



user_agent = 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0'
headers={'User-Agent':user_agent,}

# %%
def get_known(unknown_list):
    
    count_got = 0
    known_list = []
    count_checked = 0
    for word in unknown_list:
        count_checked += 1
        decision = str(input(word+"\nKnown =k"))
        if decision =='k':
            known_list.append(word)
            count_got +=1
            print("got "+str(count_got))
        elif decision=='q':
            break
        print(str(len(unknown_list)-count_checked)+' remaining')
    return known_list

# %%
def review_out(out_dict,prev_learned,eb_unk_in,eb_unk_m_in,examples,counters):
    """
    out_dict = out
    prev_learned = eb_learned
    eb_unk_in =  eb_unk
    eb_unk_m_in = eb_unk_morph
    examples = eb_unk_examples
    
    decisions:
    k = word known, remove from eb_unk and eb_unk_morph
        and add to eb_learned
        
    m = remove morph from eb_unk and eb_unk_morph 
    
    a = add example to eb_unk_examples
    q = quit for day
    """
    print(str(len(out_dict.keys()))+" total")
    counter = 0
    
    for word in out_dict.keys():
        counter += 1
        print(str(counter)+" out of "+str(len(out_dict.keys())))
        print("Lemma: "+word)
        print('')
        print("Morph: "+str(out_dict[word]['morph']))
        
        

        if len(examples[word])>0:
            print("Previous examples: ")
            for sent in examples[word]:
                print(" - "+sent)

        print("New examples: ")

        i = 0
        decision = ''
        while (i < len(out_dict[word]['sents'])) and (decision!='s')\
        and (decision!='q'):

            sent = out_dict[word]['sents'][i]
            if (sent not in examples[word]) and (sent not in counters[word]):
                print(sent)
                print('')
                decision = str(input("options : k,m,a,q,s,c"))
                if decision =='k':
                    try:
                        examples[word].append(sent) #by default adds examples
                        prev_learned[word] = eb_unk_in[word].copy()
                        del eb_unk_in[word] #remove lemma

                        i = 0
                        while i < len(eb_unk_m_in):

                            if eb_unk_m_in[list(eb_unk_m_in)[i]] == word:
                               del eb_unk_m_in[list(eb_unk_m_in)[i]]
                            else:
                                i +=1
                    except:
                        pass

                if decision =='m':
                    morph = str(input("which morph:"))
                    try:
                        del eb_unk_m_in[morph]
                        eb_unk_in[word].remove(morph) 
                    except:
                        pass
                if decision =='a':
                    try:
                        examples[word].append(sent)
                    except:
                        pass
                if decision=='c':
                    counters[word].append(sent)
                if decision =='q':
                    break
            i += 1

# %%
def how_to_add(word):
    """
    p = plain, add without conjurgating or changing
    c = conjugate as normal verb
    x = noun that adds x when plural
    s = noun that add s when plural
    iv = inner verb. There is a verb in the expression that should be 
        conjurgated
    """
    extras_morphs = []
    extras_morphs.append(word)
    
    
    gs = goslate.Goslate()

    default_conjugator = mlconjug3.Conjugator(language='fr')

    decision = str(input(word+"\nc\nx\ns\niv"))
    
    if decision == 'c':

        try:
            temp = []
            test_verb = default_conjugator.conjugate(word)
            all_conjugated_forms = test_verb.iterate()
            for item in all_conjugated_forms:
                if item not in temp:
                    temp.append(item[len(item)-1])
            extras_morphs.extend(list(set(temp)))
        except:
            pass
    elif decision == 'x':
        extras_morphs.append(lemma+'x')
    elif decision == 's':
        extras_morphs.append(lemma+'s')
    elif decision == 'iv':
        morph = str(input("which morph:"))
        

        temp = []
        test_verb = default_conjugator.conjugate(morph)
        all_conjugated_forms = test_verb.iterate()
        for item in all_conjugated_forms:
            if item not in temp:
                temp.append(item[len(item)-1])

        for variant in list(set(temp)):
            if variant is not None:
                new_word = word.replace(morph,variant)
                extras_morphs.append(new_word)

    return extras_morphs

# %%
"""
For eb_unk words: search through all articles, return 
sentences containing any words for unknown vocabulary. 

return dict object, key is lemma, then values are morphs found
and array of examples. 
"""

def find_unks(webpages,eb_unk_mo,prev_examples, prev_counter_examples):
    
    output = {}
    for webpage in webpages:
        try:

            request=urllib.request.Request(webpage,None,headers) #The assembled request
            response = urllib.request.urlopen(request)
            data = response.read()
            contents = text_from_html(data)

            contents_array = sent_tokenize(contents)

            for line in contents_array:
                tokenized = word_tokenize(line, language='french')
                for word in tokenized:
                    if word.lower() in eb_unk_mo:
                        if not bool(re.search('À lire aussi',line)):

                            if word.lower() in prev_examples:
                                if (line not in prev_examples[word.lower()]) and \
                                (line not in prev_counter_examples[word.lower()]):
                                    if word.lower() not in output:
                                        output[eb_unk_mo[word.lower()]] = {} #key will be lemma
                                        output[eb_unk_mo[word.lower()]]['morph'] = []
                                        output[eb_unk_mo[word.lower()]]['sents'] = []

                                    #disallow "" phrases

                                    output[eb_unk_mo[word.lower()]]['morph'].append(word.lower())
                                    output[eb_unk_mo[word.lower()]]['sents'].append(line)

        except:
            pass
    return output

# %%
def filter_text(webpage,text=None,print_word_lvl=False):


    #try:
    if text is None:
        request=urllib.request.Request(webpage,None,headers) #The assembled request
        response = urllib.request.urlopen(request)
        data = response.read()
        contents = text_from_html(data)
    else:
        contents = webpage

    line_array = []
    percent_array = []
    contents_array = sent_tokenize(contents)

    disallowed_words = set()
    total_words = 0
    unknown_words = 0
    lines = []
    unknowns = []
    
    for line in contents_array:
        
        line_total = 0
        line_unks = 0
        tokenized = word_tokenize(line, language='french')

        unk_str = ""
        for word in tokenized:
            total_words +=1
            line_total +=1

            if not (bool(re.search("[0-9]", word)) or\
                    bool(re.search("[A-Z]", word)) or\
                    bool(re.search("[.,\/#!$%\^&\*;:{}=\-_`~()«»]", word)) or\
                    word.lower() in vocab['white_listed']):
                if not ((word.lower() in vocab['white_listed']) or (word.lower() in vocab['black_listed'])):
                    unk_str += '"'+word.lower()+'"'+", "

                disallowed_words.add(word.lower())
                unknown_words +=1
                line_unks +=1


        line_array.append(line)
        line_percent = (line_total-line_unks)/line_total
        percent_array.append(line_percent)

        if len(unk_str)>0:
            unk_str = unk_str[0:len(unk_str)-1]

        unknowns.append(unk_str)

    if print_word_lvl and total_words>0:
        print("word-level % known = "+str((1-(unknown_words/total_words))*100))

    return_pd = pd.DataFrame(list(zip(line_array,percent_array,unknowns)))
    return_pd.columns = ["line","line_percent","unk_words"]

    with open(path+'unknown_french_dad_list.txt',"w") as outfile:
        outfile.write(str(list(disallowed_words)))

    return return_pd
    
    #except:
    #    pass

# %% [markdown]
# ##Dad section

# %%
path = "/Users/elyebliss/Desktop/Vocabulary/language_learning/vocab_dfs/"
source_file = "french_dad.json"

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13675

# %%
            
##Journal en francais facile:
print("Checking Journal en francais facile")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://francaisfacile.rfi.fr/fr/podcasts/journal-en-fran%c3%a7ais-facile/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))


pages = []
for link in soup.find_all('a', href=True):
    if '/fr/podcasts/le-journal-en-fran%C3%A7ais-facile/' in str(link['href']):
        #print(str(link['href']))
        str_page = 'https://savoirs.rfi.fr/'+str(link['href'])
        #str_page = 'https://savoirs.rfi.fr/en/apprendre-enseigner/langue-francaise/journal-en-francais-facile-'+str(re.search(r"[0-9]{8}.*",str(link['href'])).group(0))
        if str_page not in pages:
            pages.append(str_page)
print("open file:")
print(path+"text_input_web_dad_fr.txt")
for page in pages:
    print(page)
# Out:
# Checking Journal en francais facile
# open file:
# /Users/elyebliss/Desktop/Vocabulary/language_learning/vocab_dfs/text_input_web_dad_fr.txt
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221207-covid-la-chine-desserre-l-%C3%A9tau-la-cop15-%C3%A0-montr%C3%A9al-le-mondial-de-foot
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221206-l-ue-lutte-contre-la-d%C3%A9forestation-la-tv-russe-dojd-interdite-samuel-eto-o-frappe-un-youtubeur
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20221206-vladimir-poutine-bombarde-l-ukraine-appel-%C3%A0-la-gr%C3%A8ve-en-iran-nicolas-sarkozy-devant-les-juges
# https://savoirs.rfi.fr//fr/podcasts/le-journal-en-fran%C3%A7ais-facile/20
# 84  Et le Maroc, grande première pour compléter ce top 8.
# 85  Le tableau des quarts nous montre une hiérarchie de la planète foot assez conforme à ce que l'on pouvait imaginer.
# 86  Les équipes asiatiques, par exemple Japon et Corée du Sud, n'ont pas réussi en huitièmes à confirmer les espoirs suscités lors du premier tour.
# 87  Et l'Afrique, qui avait deux représentants en huitièmes de finale Sénégal et Maroc, ne peut plus compter que sur les Lions de l'Atlas, à eux, avec cette opposition face au Portugal qui se profile de faire mieux que le Cameroun en 1990, le Sénégal en 2002 et le Ghana en 2010, l'espoir d'atteindre les demi - finales en Coupe du monde, il y a peu de surprises.
# 88  Le quart entre les Pays-Bas et l'Argentine est un grand classique du Mondial.
# 89  Le Brésil, qui brigue ici une sixième étoile, retrouve le finaliste d'il y a quatre ans, la Croatie.
# 90  Quant à l'équipe de France, championne du monde en titre, elle croisera le fer avec une Angleterre demi - finaliste en 2018 et des Anglais qui font partie des huit pays à avoir déjà soulevé le trophée.
# 91  C'était en 1966.
# 92  Frédéric Suteau Doha RFI.
#
#     line_percent  \
# 0   0.884615
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   1.000000
# 5   0.960000
# 6   0.956522
# 7   1.000000
# 8   0.904762
# 9   1.000000
# 10  0.840000
# 11  0.878788
# 12  0.947368
# 13  1.000000
# 14  0.800000
# 15  0.750000
# 16  0.866667
# 17  1.000000
# 18  1.000000
# 19  0.846154
# 20  0.857143
# 21  1.000000
# 22  0.869565
# 23  0.923077
# 24  0.875000
# 25  0.857143
# 26  0.900000
# 27  0.800000
# 28  0.861111
# 29  0.848485
# 30  1.000000
# 31  0.909091
# 32  1.000000
# 33  0.941176
# 34  1.000000
# 35  0.900000
# 36  0.888889
# 37  0.928571
# 38  0.842105
# 39  0.804348
# 40  0.500000
# 41  0.909091
# 42  1.000000
# 43  1.000000
# 44  0.857143
# 45  0.944444
# 46  0.823529
# 47  0.894737
# 48  0.833333
# 49  1.000000
# 50  0.857143
# 51  0.937500
# 52  0.857143
# 53  0.937500
# 54  0.904762
# 55  0.977778
# 56  0.875000
# 57  0.941176
# 58  0.916667
# 59  0.733333
# 60  0.750000
# 61  1.000000
# 62  0.785714
# 63  1.000000
# 64  0.900000
# 65  0.833333
# 66  0.760000
# 67  0.750000
# 68  0.941176
# 69  0.823529
# 70  0.750000
# 71  0.757576
# 72  0.812500
# 73  0.944444
# 74  1.000000
# 75  1.000000
# 76  1.000000
# 77  1.000000
# 78  0.923077
# 79  1.000000
# 80  0.866667
# 81  0.733333
# 82  1.000000
# 83  0.857143
# 84  0.833333
# 85  0.761905
# 86  0.777778
# 87  0.946667
# 88  0.928571
# 89  0.818182
# 90  0.875000
# 91  1.000000
# 92  1.000000
#
#                                                                                                           unk_words
# 0   "quotidienne", "allègement", "assouplissement",
# 1
# 2
# 3
# 4
# 5   "biodiversité",
# 6   "quarts",
# 7
# 8   "évoluer", "sanitaire",
# 9
# 10  "assouplissements", "allégements", "règles", "lutter",
# 11  "positifs", "l'internement", "l'isolement", "centres",
# 12  "isolé",
# 13
# 14  "instructions", "interviennent", "pleine", "épidémique", "centres", "quarantaine", "asymptomatiques",
# 15  "loi",
# 16  "bénins", "faible", "symptôme", "s'isoleront", "désormais", "contamination",
# 17
# 18
# 19  "bâtonnets", "test", "éclaté", "sanglots",
# 20  "l'ai",
# 21
# 22  "m'envoie", "terrorisé", "l'idée",
# 23  "rassurant",
# 24  "multiplient", "dangereux", "mentalités", "isolé", "apparition",
# 25  "célibataire",
# 26  "positive", "franchement",
# 27  "refait", "déplacements",
# 28  "l'opticien", "game", "over", "magasin", "visité",
# 29  "m'inquiète", "tracas", "causer", "heureusement", "évolue",
# 30
# 31  "conseillé", "vitamines",
# 32
# 33  "blessés",
# 34
# 35  "située",
# 36  "déplore",
# 37  "processus", "lors", "retransmise",
# 38  "voire", "survivre", "d'habitants",
# 39  "potable", "coupures", "interrompus", "quotidiens", "obligés", "contraints", "voire", "s'habituer", "témoigne",
# 40  "tri",
# 41  "coupures",
# 42
# 43
# 44  "d'éventuelles", "maintenance",
# 45  "différente",
# 46  "alarmes", "retenti", "quartiers",
# 47  "l'alerte", "rétabli",
# 48  "coupure", "prévu", "calendrier",
# 49
# 50  "témoignage", "joint",
# 51  "située",
# 52  "dauphins",
# 53  "dauphins",
# 54  "impact", "faune",
# 55  "dauphins",
# 56  "d'envoi", "sauver",
# 57  "rassemble",
# 58  "défi",
# 59  "sauver", "milieux", "naturels", "nécessaires",
# 60  "d'espèces", "d'animaux", "menacées", "d'extinction",
# 61
# 62  "biodiversité", "l'équivalent", "l'accord",
# 63
# 64  "chiffres",
# 65  "populations", "vertébrés",
# 66  "quarts", "terrestre", "dégradés", "d'espèces", "s'éteindre", "d'ici",
# 67  "insectes", "pollinisateurs", "coléoptères", "recyclent", "bouses", "d'élevage", "stockent",
# 68  "indispensable",
# 69  "négociateurs", "établir", "cadre",
# 70  "préparatoires", "poussives",
# 71  "inter", "tropicaux", "biodiversité", "luxuriante", "plaident", "mers", "protégées", "d'ici",
# 72  "exportateurs", "agricoles", "obstruction",
# 73  "cœur",
# 74
# 75
# 76
# 77
# 78  "quarts",
# 79
# 80  "quart", "équipes",
# 81  "belles", "affiches", "beaux", "matchs",
# 82
# 83  "équipes", "européennes", "équipes", "l'on",
# 84  "compléter", "top",
# 85  "tableau", "quarts", "hiérarchie", "conforme", "l'on",
# 86  "équipes", "asiatiques", "huitièmes", "espoirs", "suscités", "lors",
# 87  "huitièmes", "profile", "d'atteindre", "finales",
# 88  "quart",
# 89  "brigue", "sixième", "finaliste", "d'il",
# 90  "championne", "croisera", "finaliste", "soulevé", "trophée",
# 91
# 92

# %%
all_unks = set()

with open(path+'unknown_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [re.sub("^['|\"]|^\['|['|\"]$|'\]$|\[","",line.strip().lower()) for line in new_words] #update regex
    for word in new_words:
        all_unks.add(word)
len(all_unks)
# Out:
# 164

# %%
all_unks=list(all_unks)
unk_df = pd.DataFrame(all_unks)
unk_df.columns = ['word']
unk_df['status'] = pd.Series(['' for word in all_unks])

# %%
mitosheet.sheet(unk_df, analysis_to_replay="id-mdbmtwtdut")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-mdbmtwtdut", "analysisToReplay": null, "code": [], "stepSu…

# %%
add_ints = [1, 2, 4, 5, 8, 15, 19, 20, 21, 26, 27, 33, 36, 37, 41, 42, 50, 51, 53, 56, 57, 61, 67, 71, 72, 76, 78, 83, 89, 91, 96, 106, 108, 111, 115, 126, 135, 140, 142, 144, 145, 146, 147, 148, 152, 154, 155, 157, 162, 163]

# %%
for i in add_ints:
    # Set a cell value in status
    unk_df.at[i, 'status'] = 'k'

# %%
translations = []
for i in range(0,len(unk_df)):
    try:
        translations.append(ts.google(unk_df.word.iloc[i]))
    except:
        translations.append('')
unk_df['translations']=translations

# %%
mitosheet.sheet(unk_df, analysis_to_replay="id-ianxevwttg")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-ianxevwttg", "analysisToReplay": null, "code": [], "stepSu…

# %%
add_words = list(unk_df.word[unk_df['status']=='k'])
print(len(add_words))
for word in add_words:
    vocab['white_listed'].add(word)
# Out:
# 50

# %%
filtered_art = filter_text(textfile,text= True)

# %%
filtered_art['theme']=['' for line in filtered_art.line]
filtered_art = filtered_art[['theme','unk_words','line','line_percent']]
with open(path+'dad_choose_themes.xlsx','wb') as outfile:
    filtered_art.to_excel(outfile, encoding='utf-8',index=False)

# %%
remove_words = ['colère']

for word in remove_words:
    if word in vocab['white_listed']:
        vocab['white_listed'].remove(word)

# %%
with open(path+'dad_choose_themes.xlsx','rb') as infile:
    filtered_art = pd.read_excel(infile)

# %%
themes = set(filtered_art.theme[filtered_art['theme']!='NaN'])
output = pd.DataFrame(columns=['theme','line'])
for theme in themes:
    temp = filtered_art[['theme','line']][filtered_art['theme']==theme]
    output = pd.concat([output,temp])
with open(path+'dad_article.xlsx','wb') as outfile:
    output.to_excel(outfile, encoding='utf-8',index=False)

# %%
#write to .json formats
df = vocab
df['white_listed'] = list(df['white_listed'])
df['black_listed'] = list(df['black_listed'])
with open(path+source_file, "w") as outfile:
    json.dump(df,outfile)
print(len(vocab['white_listed']))
# Out:
# 13724

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13724

# %% [markdown]
# ##Filter for lessons

# %%
with open(path+"text_input_dad_fr.txt","r") as infile:
    textfile = infile.read()
filtered_art = filter_text(textfile,text= True)
display(filtered_art)
# Out:
#                                                                                        line  \
# 0   Les hommes ont regardé le chef Eskol.
# 1   –On va abandonner nos familles ?
# 2   Nos amis ?
# 3   On ne peut pas faire ça !
# 4   –a crié un Viking.
# 5   –Regardez nos bateaux !
# 6   La tempête les a détruits !
# 7   Regardez tous ces trous !
# 8   –a dit un autre \nhomme.
# 9   –Nous ne pouvons pas retourner en toute sécurité.
# 10  Pas avec des bateaux dans cet état !
# 11  Le chef Eskol a regardé ses hommes.
# 12  –Vous avez raison tous les deux.
# 13  C’est pourquoi vous avez le choix.
# 14  Si vous voulez partir, vous êtes libres d’y aller.
# 15  Je ne vais pas vous forcer.
# 16  Si vous choisissez de rester, vous êtes les bienvenus.
# 17  A partir de maintenant, je ne suis plus votre chef.
# 18  Je suis simplement un ancien Viking.
# 19  Les jours suivants, deux groupes se sont formés.
# 20  Un groupe a décidé de rester sur les nouvelles terres.
# 21  Il essayerait d’établir une nouvelle société viking.
# 22  Le deuxième groupe prendrait les bateaux les moins endommagés.
# 23  Il essayerait de rentrer chez eux.
# 24  Un mois plus tard, le deuxième groupe est parti.
# 25  Le premier groupe l’a regardé lever l’ancre.
# 26  Les hommes du premier groupe l’ont regardé s’éloigner.
# 27  Le chef Eskol a parlé avec Thoric et Niels à côté d’un grand feu qu’ils avaient allumé.
# 28  Les flammes et la chaleur leur plaisaient.
# 29  –Je suis vraiment désolé, –a dit Eskol.
# 30  –Peu importe.
# 31  Vous vouliez seulement le bien de notre village.
# 32  Les choses n’ont pas fonctionné comme on l’avait espéré.
# 33  Mais cet endroit est un bon endroit où vivre, –lui a répondu Niels.
# 34  –Oui, –a dit Thoric.
# 35  –C’est un endroit très intéressant.
# 36  C’est bien d’être dans un nouvel endroit avec de nouvelles choses.
# 37  –Je vais continuer à explorer, chef, –a dit Niels en souriant.
# 38  –Ne vous inquiétez pas.
# 39  On va être heureux.
# 40  Les hommes ont ri.
# 41  Il n’y avait pas de haine entre eux.
# 42  Il y avait seulement de la joie.
# 43  Ils étaient prêts pour leur prochaine expédition… prêts à explorer un nouveau monde.
# 44  Un monde qui s’appellerait plus tard l’Amérique du Nord.
#
#     line_percent                 unk_words
# 0   1.000000
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   1.000000
# 5   1.000000
# 6   1.000000
# 7   0.800000      "trous",
# 8   1.000000
# 9   1.000000
# 10  1.000000
# 11  1.000000
# 12  1.000000
# 13  0.888889      "choix",
# 14  0.923077      "libres",
# 15  0.857143      "forcer",
# 16  1.000000
# 17  1.000000
# 18  1.000000
# 19  0.800000      "suivants", "formés",
# 20  1.000000
# 21  0.800000      "essayerait", "établir",
# 22  0.900000      "endommagés",
# 23  0.857143      "essayerait",
# 24  1.000000
# 25  0.916667      "ancre",
# 26  1.000000
# 27  1.000000
# 28  0.875000      "plaisaient",
# 29  0.888889      "désolé",
# 30  1.000000
# 31  1.000000
# 32  0.928571      "fonctionné",
# 33  0.933333      "–lui",
# 34  1.000000
# 35  1.000000
# 36  1.000000
# 37  1.000000
# 38  0.800000      "inquiétez",
# 39  1.000000
# 40  1.000000
# 41  0.909091      "haine",
# 42  1.000000
# 43  0.928571      "expédition…",
# 44  1.000000

# %%
with open(path+'unknown_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [re.sub("^['|\"]|^\['|['|\"]$|'\]$","",line.strip().lower()) for line in new_words] #update regex
#new_words
print(len(new_words))
known_manual = get_known(new_words)
# Out:
# 17
# établir
# Known =k
# 16 remaining
# essayerait
# Known =k
# 15 remaining
# inquiétez
# Known =k
# 14 remaining
# haine
# Known =k
# 13 remaining
# libres
# Known =k
# 12 remaining
# formés
# Known =k
# 11 remaining
# –lui
# Known =kk
# got 1
# 10 remaining
# désolé
# Known =kk
# got 2
# 9 remaining
# ancre
# Known =k
# 8 remaining
# choix
# Known =kk
# got 3
# 7 remaining
# endommagés
# Known =k
# 6 remaining
# forcer
# Known =kk
# got 4
# 5 remaining
# plaisaient
# Known =k
# 4 remaining
# fonctionné
# Known =k
# 3 remaining
# expédition…
# Known =kk
# got 5
# 2 remaining
# trous
# Known =k
# 1 remaining
# suivants
# Known =k
# 0 remaining

# %%
print(len(known_manual))
for word in known_manual:
    vocab['white_listed'].add(word)
# Out:
# 5

# %%
#known_lines_only = list(set(list(filtered_art.knowns[filtered_art.knowns != "..."])))
#known_lines_only = sorted(known_lines_only,key=len)
filtered_art = filter_text(textfile,text= True)
known_lines_only = list(filtered_art.line[filtered_art['line_percent']==1.0])
known_lines_only = sorted(known_lines_only,key=len)

# %%
known_lines_only
# Out:
# ['Nos amis ?',
#  '–Peu importe.',
#  '–a crié un Viking.',
#  'Les hommes ont ri.',
#  'On va être heureux.',
#  '–Oui, –a dit Thoric.',
#  '–Regardez nos bateaux !',
#  '–a dit un autre \nhomme.',
#  'On ne peut pas faire ça !',
#  'La tempête les a détruits !',
#  'Je ne vais pas vous forcer.',
#  '–On va abandonner nos familles ?',
#  '–Vous avez raison tous les deux.',
#  'Il y avait seulement de la joie.',
#  'C’est pourquoi vous avez le choix.',
#  'Le chef Eskol a regardé ses hommes.',
#  '–C’est un endroit très intéressant.',
#  'Pas avec des bateaux dans cet état !',
#  'Je suis simplement un ancien Viking.',
#  'Les hommes ont regardé le chef Eskol.',
#  '–Je suis vraiment désolé, –a dit Eskol.',
#  'Un mois plus tard, le deuxième groupe est parti.',
#  'Vous vouliez seulement le bien de notre village.',
#  '–Nous ne pouvons pas retourner en toute sécurité.',
#  'A partir de maintenant, je ne suis plus votre chef.',
#  'Si vous choisissez de rester, vous êtes les bienvenus.',
#  'Un groupe a décidé de rester sur les nouvelles terres.',
#  'Les hommes du premier groupe l’ont regardé s’éloigner.',
#  'Un monde qui s’appellerait plus tard l’Amérique du Nord.',
#  '–Je vais continuer à explorer, chef, –a dit Niels en souriant.',
#  'C’est bien d’être dans un nouvel endroit avec de nouvelles choses.',
#  'Mais cet endroit est un bon endroit où vivre, –lui a répondu Niels.',
#  'Ils étaient prêts pour leur prochaine expédition… prêts à explorer un nouveau monde.',
#  'Le chef Eskol a parlé avec Thoric et Niels à côté d’un grand feu qu’ils avaient allumé.']

# %%
#export knowns: [filtered_art.knowns != "..."]
#known_list = list(filtered_art.knowns)
with open(path+"known_lines_dad_fr.txt","w") as outfile:
    for line in known_lines_only:
        outfile.write(line+"\n")

# %%
#write to .json formats
df = vocab
df['white_listed'] = list(df['white_listed'])
df['black_listed'] = list(df['black_listed'])
with open(path+source_file, "w") as outfile:
    json.dump(df,outfile)
print(len(vocab['white_listed']))
# Out:
# 13675

# %%
#read from existing .json formats
with open(path+source_file, "r") as path_in:
    vocab = json.loads(path_in.read())
vocab['white_listed'] = set(vocab['white_listed'])
vocab['black_listed'] = set(vocab['black_listed'])
print(len(vocab['white_listed']))
# Out:
# 13675

# %% [markdown]
# ##EB section

# %%
#read eb unknown files from .json formats
"""
Remaining vocab size = 2186
Total learned = 181
"""
with open(path+'eb_unk.json', "r") as infile:
    eb_unk = json.loads(infile.read())
print("Remaining vocab size = "+str(len(eb_unk)))

with open(path+'eb_unk_mo.json', "r") as infile:
    eb_unk_mo = json.loads(infile.read())

with open(path+'eb_learned.json', "r") as infile:
    eb_learned= json.loads(infile.read())
print("Total learned = "+str(len(eb_learned)))

with open(path+'eb_unk_examples.json', "r") as infile:
    eb_unk_examples= json.loads(infile.read())

with open(path+'eb_unk_counter_examples.json', "r") as infile:
    eb_unk_counter_examples= json.loads(infile.read())
# Out:
# Remaining vocab size = 2186
# Total learned = 181

# %%
"""
space = plain, add without conjurgating or changing
c = conjugate as normal verb
x = noun that adds x when plural
s = noun that add s when plural
iv = inner verb. There is a verb in the expression that should be 
    conjurgated
"""
with open(path+"fr_eb_extra.txt","r") as infile:
    extras_lemmas = infile.read().split('\n')

for lemma in extras_lemmas:
    extras_morphs = how_to_add(lemma)
    
    eb_unk[lemma] = extras_morphs
    for morph in extras_morphs:        
        if morph not in eb_unk_mo:
            eb_unk_mo[morph] = lemma

print("Remaining vocab size = "+str(len(eb_unk)))

#need to add above to examples and counter examples
for lemma in eb_unk:
    if lemma not in eb_unk_examples:
        eb_unk_examples[lemma] = []
    if lemma not in eb_unk_counter_examples:
        eb_unk_counter_examples[lemma]= []
# Out:
# c
# x
# s
# iv
# Remaining vocab size = 2200

# %% [markdown]
# Get larger list of pages to search

# %%
websites = set()
with open(path+'viewed_websites_fr.txt',"r") as infile:
    for line in infile.read().split('\n'):
        websites.add(line)
print(len(websites))
# Out:
# 714

# %%
pages = []

# %%
##France24
print("Checking France24")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.france24.com/fr/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))



for link in soup.find_all('a', href=True):
    str_ver = str(link['href'])
    
    #get regex such that links start with /fr/ and don't end
    #with /
    if bool(re.search('^\/fr\/.*',str_ver)) and (str_ver[len(str_ver)-1]!='/'):
        pages.append('https://www.france24.com'+str_ver)
# Out:
# Checking France24

# %%
##20minutes
print("Checking 20minutes")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.20minutes.fr/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

for link in soup.find_all('a', href=True):
    str_ver = str(link['href'])
    
    final_segment = str_ver.split('/')[len(str_ver.split('/'))-1]
    #articles have https:// at the beginning and a date in the last segment
    if ('https://www.20minutes.fr' in str_ver)\
    and bool(re.search('[0-9]',final_segment)):
        pages.append(str_ver)
# Out:
# Checking 20minutes

# %%
##TV5Monde
print("Checking TV5Monde")
parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
#request=urllib.request.Request('https://savoirs.rfi.fr/en/apprendre-enseigner/langue-fran%C3%A7aise/journal-en-francais-facile',None,headers)
request=urllib.request.Request('https://www.tv5monde.com/',None,headers)

resp = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

for link in soup.find_all('a', href=True):
    if '/info/' in str(link['href']):
        #print(str(link['href']))
        #str_page = 'https://savoirs.rfi.fr/'+str(link['href'])
        #str_page = 'https://savoirs.rfi.fr/en/apprendre-enseigner/langue-francaise/journal-en-francais-facile-'+str(re.search(r"[0-9]{8}.*",str(link['href'])).group(0))
        if str(link['href']) not in pages:
            pages.append(str(link['href']))
# Out:
# Checking TV5Monde

# %%
pages = list(set(pages))

#add in set_difference line here
print("new = "+str(len(set(pages).difference(websites))))
pages = list(set(pages).difference(websites))
# Out:
# new = 116

# %%
out = find_unks(pages,eb_unk_mo,eb_unk_examples,eb_unk_counter_examples)

# %%
review_out(out,eb_learned,eb_unk,eb_unk_mo,eb_unk_examples,eb_unk_counter_examples)
# Out:
# 123 total
# 1 out of 123
# Lemma: sceller
#
# Morph: ['sceller', 'sceller', 'sceller', 'sceller', 'sceller', 'sceller', 'sceller']
# Previous examples:
#  - >> L'Uruguay corrige le Ghana mais les deux équipes sont éliminées Premier de son groupe, le Portugal de Cristiano Ronaldo a de grandes chances d'éviter en huitièmes le Brésil, qui tente dans la soirée de sceller sa première place du groupe H contre le Cameroun.
# New examples:
# En Iran, les autorités avancent un bilan de 200 morts depuis le début des émeutes              Sur le même sujet                07/12/2022 Le président Xi Jinping en Arabie saoudite pour sceller un rapprochement sino-arabe                 07/12/2022 Meurtre de Jamal Khashoggi : une plainte contre MBS classée sans suite aux États-Unis                 06/12/2022 Manifestations en Iran : cinq personnes condamnées à la pendaison                 06/12/2022 Mort de Shirin Abu Akleh : Al-Jazira annonce avoir soumis l'affaire au procureur de la CPI                 Révolution ?
#
# options : k,m,a,q,s,cs
# 2 out of 123
# Lemma: volée
#
# Morph: ['volée']
# Previous examples:
#  - Tous les résultats du mondial par ici Il aurait d’ailleurs pu inscrire une triplette mais sa volée (trop) ambitieuse aurait mérité de se transformer en passe en profondeur pour Marcus Thuram entré en jeu à la 63e à la place de Giroud.
#  - Mais lorsqu’un de ses membres nous l’a amené ce matin, il était soulagé de pouvoir s’en défaire, il avait peur qu’elle soit volée lors d’un cambriolage.
#  - Après une passe en profondeur du défenseur camerounais Nouhou Tolo, son coéquipier le milieu de terrain Pierre Kunde reprend d’une belle volée.
#  - L'Anglais Marcus Rashford à Doha le 29 novembre 2022  JAVIER SORIANO AFP    En face, ç'a été même pire : seule une reprise de volée de Joe Allen, du pied gauche, a animé la première période galloise (45e+5).
#  - 76e : Mendy sur ses appuis pour capter une demi volée de Plata depuis le coeur de la surface.
#  - 70e : Le défenseur reprend de volée et du plat du pied un ballon repoussé par la défense pour reprendre les devants !
#  - Elimination à distance De Arrascaeta, héros du match, double la mise quelques instants plus tard d'une volée du droit (32e, 0-1).
# New examples:
# Devant quelque 2.000 spectateurs dans un Groupama Stadium pouvant en contenir 59.000, rendant l’ambiance morose, les Lyonnaises ont rapidement pris l’avantage avec un but inscrit par l’Américaine Lindsay Horan, qui a repris de volée un centre délivré par Melvine Malard (13).
#
# options : k,m,a,q,s,ca
# 3 out of 123
# Lemma: peiner
#
# Morph: ['peiné']
# Previous examples:
#  - En face, l'Allemagne a longtemps tenu le choc défensivement, mais a beaucoup peiné à ressortir proprement les ballons, malgré tout le talent de Jamal Musiala en attaque et les rushs de Leon Goretzka pour remonter les ballons balle au pied.
# New examples:
# Mais, par la suite, l’OL a fait preuve d’un gros manque de réalisme et a peiné pour aggraver la marque.
#
# options : k,m,a,q,s,ca
# 4 out of 123
# Lemma: aggraver
#
# Morph: ['aggraver']
# Previous examples:
#  - Incapables de se montrer dangereux, les Mexicains ne reviendront jamais dans le match et laisseront même Fernandez aggraver le score avec Messi en passeur décisif (87e).
# New examples:
# Mais, par la suite, l’OL a fait preuve d’un gros manque de réalisme et a peiné pour aggraver la marque.
#
# options : k,m,a,q,s,ck
# 5 out of 123
# Lemma: mortier
#
# Morph: ['mortier']
# Previous examples:
#  - Il offre une excellence adhérence sur une multitude de supports, dont le béton, le mortier et le plâtre.
# New examples:
#     Jump to navigation                                             TV5 Monde    TV5MONDE Plus    TV    Vos rendez-vous    Guide des programmes    Revoir (replay)    Emissions    Réception TV    Direct TV      Info    Langue française    Afrique    Plus    Et aussi …    Voyage    Tivi5mondeplus    Nos applications mobiles    Flux RSS et widgets    Nous suivre sur les réseaux sociaux    TV5MONDE Presse    Marchés publics          TV5MONDE à travers le monde     TV5MONDE Amérique Latine FR, EN, ES     TV5MONDE Asie/Pacifique FR, EN     TV5MONDE Etats-Unis EN     TV5MONDE Europe FR, EN, NL, DE, RO     TV5MONDE Maghreb-Orient FR, EN, AR             INFO     Formulaire de recherche   Rechercher          Menu        Menu principal Accueil  Videos  Afrique  Terriennes  Culture  Les journaux  En continu       Suivez-nous  Facebook  Twitter             Info     Ukraine-Russie : la guerre  DIRECT - Ukraine : Vladimir Poutine reconnaît un conflit "long" en Ukraine et relativise le recours à l'arme nucléaire        Soldats ukrainiens effectuant des tirs avec un mortier français MO-120-RT-61 120 mm sur le front près de Bakhmout, dans la région de Donetsk, le 6 décembre 2022.
#
# options : k,m,a,q,s,cs
# 6 out of 123
# Lemma: voilier
#
# Morph: ['voilier']
# New examples:
# Andreï Iakounine, 47 ans, a été arrêté en octobre, accusé d'avoir utilisé l'été dernier des drones lors d'un voyage à bord de son voilier de luxe Firebird autour de cet archipel de l'Arctique, région hautement stratégique.
#
# options : k,m,a,q,s,ca
# 7 out of 123
# Lemma: parquet
#
# Morph: ['parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet', 'parquet']
# Previous examples:
#  - Le parquet espagnol avait initialement requis deux ans de prison et dix millions d'euros d'amende à l'encontre de Neymar.
#  - Trois hommes ont été interpellés et incarcérés à Nantes pour une quinzaine de vols commis au domicile de personnes âgées, selon des informations du parquet délivrées vendredi.
#  - Ces trois hommes, un père de 55 ans, son fils de 31 ans, et un autre homme de 34 ans, « ont été présentés au parquet avec l’objectif de les juger selon la procédure de comparution à délai différé », a expliqué le procureur de la République de Nantes Renaud Gaudeul.
#  - Le suspect a été présenté samedi à la justice ainsi que sa compagne en vue d’une mise en examen pour « actes de torture et de barbarie » et « assassinat », a-t-on appris auprès du parquet d’Evry.
#  - La famille avait déclaré sa disparition dans l’ Oise avant que le parquet d’Evry ne soit saisi et ouvre une information judiciaire pour « enlèvement et séquestration ».
#  - © Ludovic Marin, AFP         Texte par :  FRANCE 24  Suivre     4 mn    Le président français a assuré vendredi qu'il n'était pas au "cœur de l'enquête" du parquet national financier, qui se penche sur l'intervention des cabinets de conseil dans les campagnes de 2017 et 2022, jugeant "normal que la justice fasse son travail".
#  - "C'est normal que la justice fasse son travail, elle le fait librement", a-t-il déclaré, précisant avoir "appris (...) par la presse" les enquêtes du parquet national financier (PNF).
#  - Les décisions du PNF font suite à l'enquête préliminaire ouverte le 31 mars dernier par le parquet du chef de "blanchiment aggravé de fraude fiscale aggravée" contre McKinsey, sur la base du rapport de la commission d'enquête du Sénat relative à l'influence des cabinets de conseil privés sur les politiques publiques En ligne de mire, le cabinet de conseil américain, dont le rapport montre qu'il est intervenu dans la plupart des grandes réformes du premier quinquennat d'Emmanuel Macron (2017-2022) et jouait un rôle prépondérant auprès de son entourage.
#  - — SICCOLI PATRICK/SIPA        Deux enfants de six et neuf ans sont décédés lors de l’ incendie d’un immeuble à Onet-le-Château ( Aveyron ) ce samedi matin, a-t-on appris auprès du parquet de Rodez .
#  - Une enquête a été ouverte pour connaître les causes de l’incendie, a précisé le parquet.
#  - ©  Pierre René-Worms, France 24         Texte par :  FRANCE 24  Suivre   |   Vidéo par :  FRANCE 2     4 mn    Le parquet national financier a confirmé, jeudi, l'ouverture de deux informations judiciaires en octobre pour "tenue non-conforme des comptes de campagne" et "favoritisme et recel de favoritisme" de la part de cabinets de conseil sur les deux campagnes électorales de 2017 et 2022 du président de la République.
#  - Un petit point devant leur adversaire du jour, les Sud-Américains n'ont besoin que d'un nul pour poursuivre leur aventure en Coupe du monde, après deux belles prestations face au Qatar et aux Pays-Bas, dans le sillage d'un Enner Valencia intenable, mais incertain pour ce match.
# New examples:
# La défense avait plaidé l'acquittement, faisant notamment valoir que Iakounine, né en Russie, avait depuis 2014 la double nationalité britannique, ce qui aurait dû selon elle lui éviter les sanctions imposées aux Russes dans le sillage de la guerre en Ukraine.
#
# options : k,m,a,q,s,ca
# Des ministres aux internautes, certains imaginent déjà l’homme le plus riche du monde fouler les rochers bulgares de Belogradchik, et faire venir des touristes dans son sillage.
#
# options : k,m,a,q,s,ca
# 9 out of 123
# Lemma: âpre
#
# Morph: ['âpre']
# Previous examples:
#  - - Âpre bataille - Une partie de la nébuleuse conservatrice s'est déjà tournée vers un autre possible prétendant à la Maison Blanche et résident de Floride: son gouverneur, Ron DeSantis.
#  - L'ancien vice-président de Donald Trump, Mike Pence, son ex-chef de la diplomatie, Mike Pompeo, le gouverneur de Virginie, Glenn Youngkin... la bataille pour l'investiture républicaine promet d'être âpre.
# New examples:
# C'est la version originale ("Ur-Boris") chantée en russe qu'a choisie le directeur musical de la Scala, Riccardo Chailly, pour rester fidèle à l'esprit de Moussorgski, même si elle est "plus âpre et plus dure" , selon le directeur Dominique Meyer.
#
# options : k,m,a,q,s,ca
# 10 out of 123
# Lemma: timbre
#
# Morph: ['timbre']
# New examples:
# "Boris Godounov est un chef-d'oeuvre absolu, dont la modernité surprend" et qui réserve des "moments de grande poésie du timbre et de beauté musicale" , estime Riccardo Chailly.
#
# options : k,m,a,q,s,ca
# 11 out of 123
# Lemma: réintégrer
#
# Morph: ['réintégrer', 'réintégrer', 'réintégrer']
# New examples:
# 16h12 TU - Le CIO veut "explorer des moyens" de réintégrer Russes et Bélarusses (Bach) Le Comité international olympique veut "explorer des moyens" de réintégrer les sportifs russes et bélarusses, bannis des compétitions internationales depuis la fin février en raison de l'invasion russe de l'Ukraine, annonce ce 7 décembre son président Thomas Bach.
#
# options : k,m,a,q,s,ck
# 12 out of 123
# Lemma: donnant
#
# Morph: ['donnant', 'donnant']
# New examples:
# Toutes ses équipes étant interdites de compétition, la Russie a instauré ses propres compétitions dans plusieurs villes de Russie en leur donnant le nom de grand prix.
#
# options : k,m,a,q,s,ca
# L’astronomie n’a pas été étudiée au Kremlin, donnant la préférence aux astrologues de la cour.
#
# options : k,m,a,q,s,c
# 13 out of 123
# Lemma: esquisser
#
# Morph: ['esquisser']
# New examples:
# Cette position du CIO n'est pas nouvelle mais Thomas Bach s'y est attardé longuement, sans esquisser de pistes ni d'échéances: "cela requiert d'autres consultations et elles sont en cours, donc il n'y a pas de date fixée" , a-t-il éludé.
#
# options : k,m,a,q,s,ca
# 14 out of 123
# Lemma: foulée
#
# Morph: ['foulée', 'foulée', 'foulée', 'foulée', 'foulée', 'foulée']
# Previous examples:
#  - L’historique des échanges est effacé dans la foulée.
#  - L'opposition avait réclamé dans la foulée l'ouverture d'une enquête sur les liens entre la majorité macroniste et McKinsey.
#  - La Première ministre, qui ne dispose pas d’une majorité absolue à l’ Assemblée nationale , a donc besoin de l’appui de députés d’opposition pour espérer faire adopter sa réforme sans recourir à l’article 49.3.
# New examples:
# (Y recourir) est construit autour de ce qu'on appelle la 'frappe en représailles' : si on nous frappe, on frappe en réponse" , a déclaré Vladimir Poutine lors d'une réunion télévisée.
#
# options : k,m,a,q,s,c
# (Y recourir) est construit autour de ce qu'on appelle la 'frappe en représailles' : si on nous frappe, on frappe en réponse", a déclaré Vladimir Poutine lors d'une réunion télévisée.
#
# options : k,m,a,q,s,c
# (Y recourir) est construit autour de ce qu’on appelle la "frappe en représailles" : si on nous frappe, on frappe en réponse », a déclaré Poutine lors d’une réunion télévisée.
#
# options : k,m,a,q,s,cs
# 16 out of 123
# Lemma: rivage
#
# Morph: ['rivage', 'rivage', 'rivage', 'rivage']
# New examples:
# "La mer d'Azov est devenue une mer intérieure, c'est une chose sérieuse" , a-t-il proclamé, en référence à cette mer bordant la Russie et le sud-est de l'Ukraine dont Moscou contrôle désormais tout le rivage.
#
# options : k,m,a,q,s,ca
# Le trajet est périlleux : il va chercher des habitants qui veulent quitter leurs datchas (maisons de campagne) installées sur la rive gauche du Dniepr, celle où l'armée russe s'est repliée il y a un mois après avoir abandonné l'autre rivage et la ville de Kherson aux forces de Kiev.
#
# options : k,m,a,q,s,ca
# « La mer d’Azov est devenue une mer intérieure, c’est une chose sérieuse », a-t-il proclamé, en référence à cette mer bordant la Russie et le sud-est de l’Ukraine dont Moscou contrôle désormais tout le rivage.
#
# options : k,m,a,q,s,c
# Ces zones se trouvent souvent à proximité des côtes, mais on commence à voir que certaines d’entre elles, au large de l’Amérique, vont plus loin, vers le milieu du Pacifique, soit très loin du rivage.
#
# options : k,m,a,q,s,ca
# 17 out of 123
# Lemma: rédacteur
#
# Morph: ['rédacteur', 'rédacteur', 'rédacteur', 'rédacteur', 'rédacteur', 'rédacteur', 'rédacteur']
# Previous examples:
#  - Le directeur de la rédaction, le rédacteur en chef, et tous les autres éditeurs, qu’ils soient journalistes ou de l’encadrement, œuvrent dans le cadre et sous couvert de cette responsabilité.
#  - Il est également le rédacteur de la plainte initiale contre l'empoisonnement au chlordécone et maire écologiste de Pointe-à-Pitre dans l'attente de l'ordonnance des juges d'instruction. "
# New examples:
# Que la bataille pour l'Ukraine suscite de l'espoir ou de la peur, Volodymyr Zelensky a galvanisé le monde d'une manière que nous n'avions pas vue depuis des décennies ", a écrit le rédacteur en chef du Time, Edward Felsenthal.
#
# options : k,m,a,q,s,ck
# 18 out of 123
# Lemma: périlleux
#
# Morph: ['périlleux']
# Previous examples:
#  - Série La minisérie « The Offer » relate le tumultueux et périlleux tournage du « Parrain » Série Paramount + : Prix, films et séries, tout savoir sur ce nouveau service de streaming   Série Cannes Paca Festival Polar    Une faute ?
#  - Vite surnommé « Kolo » par les supporteurs tout comme les journalistes, le défenseur tricolore d’origine polonaise a constitué un beau teasing, dans notre championnat, au périlleux exercice qui attend de nombreux journalistes, dimanche (16 heures).
# New examples:
# Le trajet est périlleux : il va chercher des habitants qui veulent quitter leurs datchas (maisons de campagne) installées sur la rive gauche du Dniepr, celle où l'armée russe s'est repliée il y a un mois après avoir abandonné l'autre rivage et la ville de Kherson aux forces de Kiev.
#
# options : k,m,a,q,s,ck
# 19 out of 123
# Lemma: aval
#
# Morph: ['aval']
# Previous examples:
#  - « Pendant un mois, nos bénévoles vont réaliser une à deux pêches par semaine dans la carrière, où l’eau et les poissons arrivent en aval du barrage, explique Bernard Hamon, président de la fédération de pêche de Loire-Atlantique.
#  - — Jérôme Diesnis / Agence Maxele Presse       La majeure partie de l’Hérault est placée en alerte, et même en alerte renforcée pour le versant de l’Aude aval.
#  - C’est pire encore au sud-ouest du département puisque le bassin-versant de l’Aude aval a été placé en alerte renforcée.
#  - Le texte, ficelé jeudi, était suspendu à la décision de la Pologne, qui vient de donner son aval ce vendredi.
#  - 17h57 : Accord de l’UE sur plafonnement des prix du pétrole russe après aval de Varsovie Les 27 pays de l’Union européenne ont trouvé un accord sur le plafonnement à 60 dollars par baril des prix du pétrole russe après le feu vert donné par Varsovie, a annoncé vendredi à Bruxelles le représentant de la Pologne.
# New examples:
# Sur la rive orientale occupée, en aval de Kherson, l'île Potemkine, longue d'environ huit kilomètres sur quatre de large, abrite plusieurs centaines de maisons de campagne bâties sur les bords de la rivière Prohnii, qui coupe en partie le sud de l'île.
#
# options : k,m,a,q,s,ca
# 20 out of 123
# Lemma: esquisse
#
# Morph: ['esquisse']
# New examples:
# 05h32 TU - Guerre oblige, les touristes russes débarquent sur les plages paradisiaques du Venezuela​ Dimitri Bobkov esquisse quelques pas de danse sur un rythme de merengue dans une station-service de Margarita, une île du Venezuela qu'il visite pour la première fois et attire des milliers de Russes qui y trouvent un décor paradisiaque loin de la guerre.  "
#
# options : k,m,a,q,s,cs
# 21 out of 123
# Lemma: aérodrome
#
# Morph: ['aérodrome', 'aérodrome', 'aérodrome', 'aérodrome']
# New examples:
# 04h05 TU - Les Américains mitigés après une nouvelle attaque sur une base russe  Washington a déclaré " ne pas encourager " les attaques ukrainiennes de drones en Russie, alors que Moscou a signalé qu'un de ces engins avait touché mardi 6 décembre un aérodrome près de la frontière, sans faire de victime.
#
# options : k,m,a,q,s,cs
# 22 out of 123
# Lemma: éphémère
#
# Morph: ['éphémère', 'éphémère', 'éphémère', 'éphémère', 'éphémère', 'éphémère']
# Previous examples:
#  - « Chacun peut aussi venir déjeuner pour une dizaine d’euros, boire un verre dans un bar éphémère ou encore suivre son cheval préféré jusque dans les écuries [sous conditions] », précise également Valérie François.
#  - « Je me suis dit que c’était l’occasion ou jamais » Quand la mère de Jean-Pierre a entendu parler de ce dispositif éphémère par la presse, il y a quinze jours, elle a appelé son fils pour lui demander de se défaire « de l’arme de mon grand-père qui se trouvait dans le grenier ».
#  - Carton jaune pour l’ancien éphémère Lillois à cause de ce coude baladeur.
#  - Il y a plusieurs éléments à prendre en compte : la qualité du produit, la durabilité ou au contraire cet effet éphémère pouvant avoir tout son charme en attendant le Noël prochain.
# New examples:
# Les JT - sidebar  Le 12'     En continu      03:42    Pérou: Pedro Castillo, un éphémère président lui aussi destitué par le Parlement      03:39    Pérou: Pedro Castillo destitué et arrêté, sa vice-présidente investie      02:54    La sexualité et les Iraniennes à l'honneur pour le grand retour du festival du film de Sundance      02:26    Poutine reconnaît un conflit "long" en Ukraine, relativise le recours à l'arme nucléaire      Tout le fil         Suivez-nous   Facebook   Twitter   Google +     Focus         Collection Reportages    [Collection Reportages] met en lumière des histoires, des documents, des portraits ou encore des enquêtes.
# options : k,m,a,q,s,cs
# 23 out of 123
# Lemma: rouage
#
# Morph: ['rouage', 'rouage', 'rouage']
# New examples:
# Français   English   Español   عربي                                 Naviguer hors connexion                 S'abonner aux newsletters                  Gérer mes consentements                   Emissions   Reportages                  France   Afrique   Moyen-Orient   Europe   Amériques   Asie-Pacifique          Accéder au contenu principal       France 24 - Infos, news & actualités - L'information internationale en direct                                                                                                      /  Culture      DOCUMENTAIRE   Cinéma : "L’évasion fiscale n’est pas un défaut mais un rouage du système"                  Publié le : 07/12/2022 - 07:01          Visuel du film "La (très) grande évasion", documentaire de Yannick Kergoat sur l'évasion fiscale, sorti au cinéma le 7 décembre.
#
# options : k,m,a,q,s,cs
# 24 out of 123
# Lemma: brèche
#
# Morph: ['brèche']
# Previous examples:
#  - Il interdit aussi aux concurrents de s’engouffrer dans la brèche.
#  - "Ce que je fais avec ma musique, c'est tout petit, mais en même temps, c'est une brèche pour parler de la situation des femmes en Iran.
# New examples:
# Tout le monde s'engouffre dans la brèche et on se retrouve avec une énorme industrie de l'évasion fiscale qui travaille à réaliser ces montages, incluant les banques, les cabinets de conseil, les lobbys, les prête-noms, les gestionnaires de fortune et j'en passe.
#
# options : k,m,a,q,s,cs
# 25 out of 123
# Lemma: feuilleton
#
# Morph: ['feuilleton']
# New examples:
# Mais le travail journalistique publié sous forme de feuilleton a ses limites : les " Panama Papers " (2016) ont fait beaucoup plus de bruit que les " Pandora Papers " (2021), alors que les révélations étaient beaucoup plus importantes lors du second scandale.
#
# options : k,m,a,q,s,cs
# 26 out of 123
# Lemma: loupe
#
# Morph: ['loupe']
# New examples:
# De plus, ces enquêtes génèrent un effet loupe : on voit la trompe, on voit la patte de l'évasion fiscale mais jamais l'éléphant en entier.
#
# options : k,m,a,q,s,cs
# 27 out of 123
# Lemma: souplesse
#
# Morph: ['souplesse', 'souplesse']
# New examples:
# Ce dernier, qui avait fait du "zéro Covid" sa marque de fabrique, a désormais infléchi son discours, reconnaissant que le variant Omicron, moins mortel, "ouvre la voie à plus de souplesse dans les restrictions".
#
# options : k,m,a,q,s,css
# Ce dernier, qui avait fait du " zéro Covid " sa marque de fabrique, a désormais infléchi son discours, reconnaissant que le variant Omicron, moins mortel, " ouvre la voie à plus de souplesse dans les restrictions ".
# New examples:
# Il contrôle, se retourne et fusille la lucarne gauche de Sommer (17 e , 1-0).
#
# options : k,m,a,q,s,cs
# 30 out of 123
# Lemma: pépé
#
# Morph: ['pépé']
# Previous examples:
#  - A compter de ce vendredi et jusqu’au 25 novembre, les particuliers ont en effet la possibilité de venir déposer le vieux fusil hérité de pépé dont ils veulent se débarrasser.
# New examples:
# Si Fabian Schär manque d'offrir le break au Portugal d'un but contre son camp (32 e ), c'est bien Pépé qui double la mise sur un corner exécuté par Bruno Fernandes (33 e , 2-0).
#
# options : k,m,a,q,s,cs
# 31 out of 123
# Lemma: essor
#
# Morph: ['essor']
# New examples:
# Covid-19, concurrence des ventes en ligne , inquiétudes sur le pouvoir d’achat, essor du marché de la seconde main, etc.
#
# options : k,m,a,q,s,cs
# 32 out of 123
# Lemma: ruée
#
# Morph: ['ruée']
# New examples:
# Plus d’informations à venir sur 20minutes.fr…/… Économie La vente aux enchères du fichier client de Camaïeu pose question Société Ruée sur les vêtements Camaïeu bradés dans un magasin de Côte-d'Or   Économie Camaïeu Rachat Vetement Covid 19    Une faute ?
#
# options : k,m,a,q,s,cs
# 33 out of 123
# Lemma: frôler
#
# Morph: ['frôler', 'frôler']
# Previous examples:
#  - Ils n'hésitent pas à reprendre dans leurs campagnes les codes du rap, des jeux-vidéo et de la banlieue, quitte à frôler l'illégalité.
#  - Les statistiques étaient remontées régulièrement depuis, jusqu'à frôler ce plus-haut historique le mois dernier, avec 72 350 personnes incarcérées au 1er octobre.
# New examples:
# Au risque, parfois, de frôler la publicité mensongère.
#
# options : k,m,a,q,s,cs
# 34 out of 123
# Lemma: écho
#
# Morph: ['écho', 'écho']
# Previous examples:
#  - La Commission de la santé et des services sociaux des Premières Nations du Québec et du Labrador espère que ce rapport et les recommandations trouveront écho.
#  - Après avoir été longtemps ignorée des politiques, qui estimaient ce projet impossible au vu de l’actuelle saturation des lignes ferroviaires, cette association « transpartisane et indépendante » a reçu un écho plus favorable ces dernières semaines.
#  - On a encore l'opportunité de se qualifier, nous aimons bien prendre le chemin le plus difficile pour atteindre nos objectifs...»     16h55 : « Nos pensées vont au peuple iranien, mais » L'affiche Iran - Etats-Unis de mardi (20 heures) aura évidemment un écho autre que footballistique.
#  - A 20 heures, choc à l’écho symbolique entre l’Iran et les Etats-Unis, là aussi déterminant pour une place en huitièmes.
#  - Pays de Galles - Angleterre EN DIRECT : Les Three Lions peuvent-ils un peu trembler face au voisin gallois ?… Suivez le match avec nous dès 19h30… Iran - Etats-Unis EN DIRECT : Un choc encore plus sous haute tension qu'au Mondial 1998... Vivez le match avec nous dès 19h30...    22h32 : L’une des punchlines du jour est pour le premier adjoint d’Anne Hidalgo Pour sortir un peu de l’actu Mondial, on vous fait écho des relations tendues entre la direction du PSG et la ville de Paris.
#  - Des propos auxquels plusieurs ministres de l'Alliance, rejoints par leurs homologues de Suède et de Finlande, deux pays candidats à l'adhésion, ont fait écho.
#  - Puissent ces paroles trouver un nouvel écho lors du match de mardi.
#  - Un message qui risque de ne pas trouver d’écho, jeudi, à Beyrouth.
#  - Ces accusations d’agression font écho à d’autres lancées par des spectatrices à l’occasion de l’avant-première d’un film, en mars dernier à Bruxelles, en Belgique.
#  - La scène de 7 minutes fait étrangement écho aux accusations d’agression sexuelle lancées par une jeune femme dans la vraie vie à l’égard de l’acteur et dramaturge français.
# New examples:
# Un commentaire qui pourrait bien faire écho aux propos du prince Harry et de Meghan Markle, qui promettent, eux, de dévoiler « la vérité » que « personne ne connaît » (sauf eux) sur la royauté britannique, lorsque « les portes sont fermées ».
# options : k,m,a,q,s,cs
# 35 out of 123
# Lemma: marécage
#
# Morph: ['marécage']
# New examples:
# Un hippopotame dans un marécage en Ouganda, en février 2022.
#
# options : k,m,a,q,s,cs
# 36 out of 123
# Lemma: pupitre
#
# Morph: ['pupitre', 'pupitre']
# Previous examples:
#  - Debout derrière un pupitre en bois sur une plage du pays, il a annoncé, dans une vidéo , que le petit pays insulaire du Pacifique allait devenir la première nation numérique du monde.
# New examples:
# Le sexagénaire cherchait à s'emparer du siège de Raphael Warnock, qui avant de devenir en 2021 sénateur de Géorgie officiait en tant que pasteur depuis l'ancien pupitre de Martin Luther King, à Atlanta.
#
# options : k,m,a,q,s,cs
# 37 out of 123
# Lemma: sape
#
# Morph: ['sape', 'sape', 'sape']
# Previous examples:
#  - G20 : " la plupart des membres condamnent fermement la guerre en Ukraine"​ La "plupart" des membres du G20, "ont condamné fermement la guerre en Ukraine" et tous se sont accordés sur le fait que le conflit "sape l'économie mondiale" , selon un communiqué commun publié mercredi à l'issue du sommet du groupe à Bali.
# New examples:
# "La censure d'un média russe indépendant sape les efforts de lutte contre la propagande du Kremlin, l'objectif même des autorités lettones", a déclaré l'organisation sur sa page internet.
#
# options : k,m,a,q,s,cs
# 38 out of 123
# Lemma: dénouer
#
# Morph: ['dénouer']
# New examples:
# 17 h 08 : l'UE toujours enlisée dans son bras de fer avec la Hongrie  L'Union européenne (UE) et la Hongrie ont échoué à dénouer leur conflit sur l'État de droit.
#
# options : k,m,a,q,s,cs
# 39 out of 123
# Lemma: salve
#
# Morph: ['salve']
# Previous examples:
#  - 13 h 40 : une alerte aérienne est déclenchée dans toute l'Ukraine  Une alerte aérienne a été déclenchée dans toute l'Ukraine après des avertissements des autorités ukrainiennes sur des préparatifs par la Russie d'une nouvelle salve de tirs de missiles et d'attaques de drones.
# New examples:
# h 51 : l'Ukraine transie de froid répare ses installations énergétiques après une attaque russe  L'Ukraine s'efforce encore mardi de réparer ses installations énergétiques , endommagées par une nouvelle salve de missiles russes, et de réapprovisionner les Ukrainiens privés de courant et d'eau au moment où des températures polaires frappent le pays.
#
# options : k,m,a,q,s,cs
# 40 out of 123
# Lemma: somnoler
#
# Morph: ['somnoler']
# New examples:
# Quelques heures à somnoler (plus qu’à dormir) plus tard, sans surprise, nouvel interlocuteur, nouveau son de cloche.
#
# options : k,m,a,q,s,cs
# 41 out of 123
# Lemma: costard
#
# Morph: ['costard']
# New examples:
# Un officiel de l’ambassade Ougandaise, une armoire à glace dans un costard gris flashy, accepte finalement de recevoir Paul.
#
# options : k,m,a,q,s,cs
# 42 out of 123
# Lemma: val
#
# Morph: ['val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', 'val', '
#  - C’est parti pour un mois d’émerveillement et de festivités.
# New examples:
# » Je vous fais grâce du reste, mais sachez que tout le champ lexical de l’émerveillement y passe.
#
# options : k,m,a,q,s,cs
# 104 out of 123
# Lemma: repenser
#
# Morph: ['repenser']
# Previous examples:
#  - TICAD8 — permettre aux pays africains de mener leur propre développement Comment repenser la coopération au développement en Afrique dans le contexte des crises actuelles ?
#  - Nous sommes tous en train de repenser non seulement notre façon de travailler, mais aussi pourquoi nous travaillons.
# New examples:
# Ca nous fait repenser à notre sujet de la saison passée sur les meilleurs dribbleurs de Ligue 1.
#
# options : k,m,a,q,s,cs
# 105 out of 123
# Lemma: hisser
#
# Morph: ['hisser']
# Previous examples:
#  - — Martin Meissner/AP/SIPA        Après Vincent Luis en 2019 et 2020, un autre athlète tricolore vient de se hisser sur le toit du monde en triathlon .
#  - Le succès japonais cumulé à la trop faible victoire allemande a permis aux Nippons, premiers du groupe E avec six points, de se hisser une nouvelle fois en 8es de finale avec les Espagnols, qui ont conservé une différence de buts plus favorable par rapport à l’Allemagne (+6 contre 1), les deux sélections terminant à quatre points.
#  - En 2000 et en 2004, elle avait quitté l’Euro dès le premier tour, avant de se hisser en demi-finales du Mondial 2006 à domicile deux ans plus tard.
# New examples:
# Pour rappel, le Maroc ne devient que le quatrième pays africain à se hisser dans les quarts de finale d’une Coupe du monde.
#
# options : k,m,a,q,s,cs
# 106 out of 123
# Lemma: remous
#
# Morph: ['remous', 'remous']
# New examples:
# La Coupe du monde se poursuit au Qatar , et on continue de vous faire vivre la compétition de bon matin avec notamment les remous de l’élimination espagnole, la fiesta monstrueuse au Maroc et le carton du Portugal face à la Suisse sans Cristiano Ronaldo .
#
# options : k,m,a,q,s,cs
# 107 out of 123
# Lemma: relevé
#
# Morph: ['relevé', 'relevé']
# Previous examples:
#  - Hong Kong a relevé son alerte au niveau trois et s'attend dans les prochaines heures à des vents violents et d'importantes précipitations.
#  - Jusqu'à présent, "63 corps" ont été retrouvés "mais les recherches ne font que commencer et beaucoup plus de sites de torture et de mises en terre seront découverts", a-t-il relevé, selon le site du gouvernement ukrainien.
#  - Après s’être relevé, Ismaïla Sarr transforme lui-même ce pénalty.
#  - "Il y a un chemin étroit, mais qui existe, pour sauver la Grande Barrière", a relevé une source proche du dossier.
#  - D’après Europe 1, l’agent se serait relevé en déclinant sa qualité et en montrant son arme de service.
# New examples:
# "Nous avons aussi relevé la disparition de 92 espèces d'amphibiens, tués à cause de la prolifération d'un champignon.
#
# options : k,m,a,q,s,cs
# 108 out of 123
# Lemma: repère
#
# Morph: ['repère']
# New examples:
# L'Atlético de Madrid le repère et lui propose un contrat de quatre ans.
# options : k,m,a,q,s,ca
# 109 out of 123
# Lemma: ressentiment
#
# Morph: ['ressentiment']
# New examples:
# Twitter       Publié le 07/12/22 à 11h50 — Mis à jour le 07/12/22 à 12h19       64    commentaires    2K   partages       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Cristiano Ronaldo n'a pas caché son ressentiment envers le choix de Fernando Santos, mardi soir, durant la large victoire de la sélection portugaise contre la Suisse (6-1).
#
# options : k,m,a,q,s,cs
# 110 out of 123
# Lemma: carreau
#
# Morph: ['carreau']
# Previous examples:
#  - Après des semaines de lutte, pas moins de 77 employés se retrouvent sur le carreau.
# New examples:
# Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   Société  L’une des deux boulangeries de Groix va fermer à cause du prix de l’énergie      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Société Faits divers Politique Monde Santé Justice     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Guerre en Ukraine Coupe du monde 2022 Journée mondiale du climat      Voir les tags précedents     Voir les tags suivants                    Accueil Société   Crise énergétique : L’une des deux seules boulangeries de Groix contrainte de fermer   FERMETURE  Le commerce de l’île baissera définitivement le rideau le 31 décembre, laissant sur le carreau trois salariés     J.G.
#
# options : k,m,a,q,s,cs
# 111 out of 123
# Lemma: prêcheur
#
# Morph: ['prêcheur']
# New examples:
# C’est ainsi que, selon l’Intérieur, les juifs et les chrétiens sont « qualifiés de corrupteurs (hadith qu’il utilise) » par le prêcheur.
#
# options : k,m,a,q,s,ca
# 112 out of 123
# Lemma: repli
#
# Morph: ['repli']
# Previous examples:
#  - © Capture d'écran, France 24     Appel à un dialogue direct Le mini-sommet de Luanda a décidé une cessation des hostilités dès vendredi soir dans l'est de la République démocratique du Congo, suivie du retrait des rebelles du M23 "des zones occupées" et de leur "repli dans leurs positions initiales".
# New examples:
# Beauvau a fait valoir que ces propos « tenus en 2020 » s’apparentaient « clairement à un encouragement au séparatisme et au repli communautaire ».
#
# options : k,m,a,q,s,cs
# 113 out of 123
# Lemma: cerner
#
# Morph: ['cerner']
# Previous examples:
#  - Toujours difficile à cerner derrière son personnage provocateur, misogyne et « foncedé », Lorenzo n’a jamais donné une interview « sérieuse » , préférant se ranger derrière son bob Game Boy Color, ses grosses lunettes et sa moustache.
# New examples:
# Une autopsie doit être réalisée pour cerner les causes du décès.
#
# options : k,m,a,q,s,ca
# 114 out of 123
# Lemma: converser
#
# Morph: ['converser']
# New examples:
# Début 2023, sur iMessage, ils auront des garanties supplémentaires contre le risque de converser avec des usurpateurs d’identité.
#
# options : k,m,a,q,s,ca
# 115 out of 123
# Lemma: émoi
#
# Morph: ['émoi', 'émoi', 'émoi']
# New examples:
# Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   High-Tech  Elon Musk, le roi de la provoc' sur Twitter      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Jeux vidéo Sciences Espace Réseaux sociaux Amazon Google Facebook Apple     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Guerre en Ukraine Coupe du monde 2022 Journée mondiale du climat      Voir les tags précedents     Voir les tags suivants                    Accueil High-Tech   « Brokeback mountain », flingue et cocaïne... Les cinq tweets les plus « WTF » d'Elon Musk   sans filtre  Elon Musk prône la liberté d’expression totale sur Twitter et semble s’amuser de l’émoi que peuvent provoquer ses tweets     Charlotte Murat     Publié le 07/12/22 à 18h27       5    commentaires    0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Elon Musk, le roi de la provoc sur Twitter — 20 Minutes       « Quasiment certain que c’était dans Elden Ring », a ce mardi écrit Elon Musk sous la photo d’une impressionnante forteresse bulgare.
#
# options : k,m,a,q,s,cs
# 116 out of 123
# Lemma: forteresse
#
# Morph: ['forteresse', 'forteresse']
# New examples:
# Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   High-Tech  Elon Musk, le roi de la provoc' sur Twitter      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Jeux vidéo Sciences Espace Réseaux sociaux Amazon Google Facebook Apple     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Guerre en Ukraine Coupe du monde 2022 Journée mondiale du climat      Voir les tags précedents     Voir les tags suivants                    Accueil High-Tech   « Brokeback mountain », flingue et cocaïne... Les cinq tweets les plus « WTF » d'Elon Musk   sans filtre  Elon Musk prône la liberté d’expression totale sur Twitter et semble s’amuser de l’émoi que peuvent provoquer ses tweets     Charlotte Murat     Publié le 07/12/22 à 18h27       5    commentaires    0   partage       Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Pinterest       Partager sur Linkedin       Imprimer       Envoyer par Mail       Sauvegarder l'article          Elon Musk, le roi de la provoc sur Twitter — 20 Minutes       « Quasiment certain que c’était dans Elden Ring », a ce mardi écrit Elon Musk sous la photo d’une impressionnante forteresse bulgare.
#
# options : k,m,a,q,s,cs
# 117 out of 123
# Lemma: fouler
#
# Morph: ['fouler']
# Previous examples:
#  - Cette nouvelle capsule, qui doit emmener dans les prochaines années des astronautes sur la Lune - les premiers à en fouler la surface depuis la dernière mission Apollo en 1972 -, voyage ainsi actuellement à plus de 64.000 kilomètres de la Lune.
# New examples:
# Des ministres aux internautes, certains imaginent déjà l’homme le plus riche du monde fouler les rochers bulgares de Belogradchik, et faire venir des touristes dans son sillage.
#
# options : k,m,a,q,s,cs
# 118 out of 123
# Lemma: chevet
#
# Morph: ['chevet']
# Previous examples:
#  - Fake Off    By the Web    High-Tech    20 Mint    Vidéos    Podcasts    En Images    Guide d'achat    Le direct    Jeux    Services    Journal numérique    Minutes Maison      Menu complet        Retour à l’accueil   Sport  L’ancien entraîneur de Reims Oscar Garcia annonce le décès de sa fille      Partager sur Messenger       Partager sur Facebook       Partager sur Twitter       Partager sur Flipboard       Partager sur Linkedin        Sauvegarder l'article       Menu complet        Fermer          Coupe du monde 2022 Live score Basket Biathlon Cyclisme Football Formule 1 Mercato Rugby Tennis Sportune     Voir les sous-sections précedentes     Voir les sous-sections suivantes          Dans l’actu Coupe du monde 2022 Guerre en Ukraine Black Friday Inflation      Voir les tags précedents     Voir les tags suivants                    Accueil Sport   Ligue 1 : L’ancien entraîneur de Reims Oscar Garcia annonce le décès de sa fille   DRAME  Oscar Garcia a annoncé le décès de sa fille, au chevet de laquelle il se rendait fréquemment lorsqu’il entraînait Reims avant d’être renvoyé en octobre     N.S.
#  - Et s’il promet de venir au chevet de son employé, Paul l’attendra en vain dans sa chambre.
# New examples:
# notre dossier sur elon musk Volontairement provocateur, il se moque de choquer les internautes avec la photo d’une arme à feu sur sa table de chevet ou en soumettant au vote son plan pour mettre fin à la guerre en Ukraine.
# options : k,m,a,q,s,cs
# 119 out of 123
# Lemma: gammée
#
# Morph: ['gammée']
# Previous examples:
#  - © Antonio Moreira, AFP         Texte par :  FRANCE 24  Suivre     4 mn    Le visage couvert et une croix gammée sur ses vêtements, un jeune brésilien de 16 ans a tué au moins trois personnes, vendredi, et fait 11 blessés dans deux établissements scolaires de l'État d'Espirito Santo, dans le sud-est du Brésil.
#  - Et, ce vendredi, Twitter a suspendu son compte pour « incitation à la violence », après qu’il a publié une image représentant une croix gammée entrelacée avec une étoile de David.
# New examples:
# Le 2 décembre, il a suspendu le compte Twitter de Kanue West , après que ce dernier a posté une croix gammée.
#
# options : k,m,a,q,s,cs
# 120 out of 123
# Lemma: orgue
#
# Morph: ['orgue']
# Previous examples:
#  - Les très incertains groupes E et F sont à l’honneur, avec en point d’orgue à 20 heures le choc Espagne - Allemagne, qui pourrait constituer le pic de dramaturgie de ce premier tour du Mondial.
#  - Cette mobilisation est le point d’orgue d’une grogne populaire qui couve depuis des mois en Chine face aux restrictions sanitaires et la politique « zéro-Covid » appliquée depuis bientôt trois ans.
# New examples:
# Et puis le point d’orgue, sa lettre à Didier Deschamps lui expliquant qu’il rejetait le rôle de réserviste pour le Mondial 2018.
#
# options : k,m,a,q,s,ca
# 121 out of 123
# Lemma: abattoir
#
# Morph: ['abattoir']
# New examples:
# Français   English   Español   عربي                                 Naviguer hors connexion                 S'abonner aux newsletters                  Gérer mes consentements                   Emissions   Reportages                  France   Afrique   Moyen-Orient   Europe   Amériques   Asie-Pacifique          Accéder au contenu principal       France 24 - Infos, news & actualités - L'information internationale en direct                                                                                                   Allemagne : la plus grosse production de cannabis "indoor" en Europe                  Publié le : 07/12/2022 - 18:25 Modifié le : 07/12/2022 - 20:10                  03:22   cannabis  © afp         Vidéo par :  Gaëlle FONSECA      La start-up allemande Demecan fait pousser depuis un an de la marijuana "made in Germany" dans un ancien abattoir au milieu des champs, décor typique de l'est de l'Allemagne.
#
# options : k,m,a,q,s,cs
# 122 out of 123
# Lemma: requérir
#
# Morph: ['requérir', 'requérir', 'requérir', 'requérir']
# New examples:
# © Marine brésilienne via AFP         Texte par :  FRANCE 24  Suivre     4 mn    Le parquet a estimé mercredi "ne pas être en mesure de requérir la condamnation" d'Airbus et d'Air France, jugés pour homicides involontaires après le crash du vol Rio-Paris, dans lequel 228 personnes sont mortes le 1er juin 2009.
#
# options : k,m,a,q,s,cs
# 123 out of 123
# Lemma: merle
#
# Morph: ['merle']
# New examples:
# © Philippe Merle, AFP    Ses performances lui valent d'être appelé au sein des Lions de l'Atlas en 2001.
#
# options : k,m,a,q,s,cs

# %%
#could remove junk examples that include "À lire aussi" -> done
# make it possible to skip until the end without reviewing all examples
# show list of unique words and option to go to them

# %%
for word in pages:
    websites.add(word)
with open(path+'viewed_websites_fr.txt',"w") as outfile:
    for line in websites:
        outfile.write(line+'\n')

# %%
#write to eb unknown files to .json formats
"""
Remaining vocab size = 2177
Total learned = 190
"""
with open(path+'eb_unk.json', "w") as outfile:
    json.dump(eb_unk,outfile)
print("Remaining vocab size = "+str(len(eb_unk)))

with open(path+'eb_unk_mo.json', "w") as outfile:
    json.dump(eb_unk_mo,outfile)

with open(path+'eb_learned.json', "w") as outfile:
    json.dump(eb_learned,outfile)
print("Total learned = "+str(len(eb_learned)))

with open(path+'eb_unk_examples.json', "w") as outfile:
    json.dump(eb_unk_examples,outfile)

with open(path+'eb_unk_counter_examples.json', "w") as outfile:
    json.dump(eb_unk_counter_examples,outfile)
# Out:
# Remaining vocab size = 2177
# Total learned = 190

# %% [markdown]
# ### Code no longer in use

# %%
def return_line_percents(webpage):
    request=urllib.request.Request(webpage,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read()
    contents = text_from_html(data)

    known_array = []
    unk_array = []
    contents_array = sent_tokenize(contents)

    lines = []

    for line in contents_array:
        tokenized = word_tokenize(line, language='french')

        line_total = 0
        line_unks = 0
        for word in tokenized:

            line_total +=1

            if not (bool(re.search("[0-9]", word)) or\
                    bool(re.search("[A-Z]", word)) or\
                    bool(re.search("[.,\/#!$%\^&\*;:{}=\-_`~()«»]", word)) or\
                    word.lower() in vocab['white_listed']):

                    line_unks +=1

            lines.append(100*(line_total-line_unks)/line_total)
    return(lines)

# %%
if (start is not None) and (stop is not None):
    contents_array=contents_array[max(start,0):min(stop,len(contents_array))]

with open(path+'unknown_french_dad_list.txt',"w") as outfile:
    outfile.write(str(list(disallowed_words)))

# %%
##add in extras
with open("/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/fr_eb_extra.txt","r") as infile:
    extras_lemmas = infile.read().split('\n')

gs = goslate.Goslate()

default_conjugator = mlconjug3.Conjugator(language='fr')


for lemma in extras_lemmas:
    
    decision = how_to_add(lemma)
    
    if lemma not in eb_unk:
        eb_unk[lemma] = []
        
    extras_morphs = []
    extras_morphs.append(lemma)
    try:
        #if it's an infinitive, add all conjurgations
        test_verb = default_conjugator.conjugate(lemma)
        all_conjugated_forms = test_verb.iterate()
        for item in all_conjugated_forms:
            if item not in extras_morphs:
                extras_morphs.append(item[len(item)-1])
        extras_morphs = list(set(extras_morphs))
    except:
        
        #if not an expression:
        if len(lemma.split(' '))==1:
            #add plural nouns
            if lemma[len(lemma)-1]=='u':
                extras_morphs.append(lemma+'x')
            else:
                extras_morphs.append(lemma+'s')

    eb_unk[lemma] = extras_morphs
    for morph in extras_morphs:        
        if morph not in eb_unk_mo:
            eb_unk_mo[morph] = lemma

print("Remaining vocab size = "+str(len(eb_unk)))
# Out:
# Remaining vocab size = 2327

# %%
#Upload from download
with open(path+'known_french_dad_list.txt',"r") as input_file:
    new_words = input_file.read()
    new_words = re.sub('\n',"",new_words)
    new_words = new_words.split(',')
    new_words = [line.replace('"',"").strip().lower() for line in new_words]
    print("daily catch in word count:")
    print(len(new_words))
    
    for line in new_words:   
        vocab['white_listed'].add(line.replace('"',"").strip().lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 #Upload from download
# ----> 2 with open(path+'known_french_dad_list.txt',"r") as input_file:
#       3     new_words = input_file.read()
#       4     new_words = re.sub('\n',"",new_words)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/known_french_dad_list.txt'

# %%
"""
to do:

"""

# %%
##INPUT-OUTPUT
#vocab list:
with open("/Users/elyebliss/Desktop/Vocabulary/vocab_dfs/dad_whitelisted.csv","r") as infile:
    whitelisted_lemmas = infile.read()


##VARIABLES
vocab_all = set()
gs = goslate.Goslate()

default_conjugator = mlconjug3.Conjugator(language='fr')


for line in whitelisted_lemmas.split('\n'):
    if len(line) > 0:
        #print(line)
        vocab = line.lower().strip()
        vocab_all.add(vocab)
        try:
            #if it's an infinitive, add all conjurgations
            test_verb = default_conjugator.conjugate(vocab)
            all_conjugated_forms = test_verb.iterate()
            for item in all_conjugated_forms:
                
                vocab_all.add(item[len(item)-1])
                
            
        except:
            #might be a noun, add plural
            vocab_all.add(add_noun(vocab))
#len(whitelisted_lemmas.split('\n'))            
#pp.pprint(vocab_all)

# %%
vocab = {}
vocab['white_listed'] = list(vocab_all)
vocab['black_listed'] = []

# %%
#used for creating eb data

with open(path+'eb_unk_lemmas.csv','r') as infile:
    eb_unk_lemmas = pd.read_csv(infile)
with open(path+'eb_unk_morph.csv','r') as infile:
    eb_unk_morph = pd.read_csv(infile)
    
eb_unk = {}
for word in eb_unk_lemmas.lemme:
    eb_unk[word] = []

    for index, row in eb_unk_morph.iterrows():
        if row.lemme == word:
            eb_unk[word].append(row.ortho)
eb_unk_mo = {}
for lemma in eb_unk.keys():
    for morph in eb_unk[lemma]:
        eb_unk_mo[morph] = lemma

# %%
eb_learned = {}
eb_unk_examples = {}
for word in eb_unk.keys():
    eb_unk_examples[word] = []

# %%
#restore to backups
eb_learned = eb_learned_backup
eb_unk = eb_unk_backup
eb_unk_mo = eb_unk_mo_backup
eb_unk_examples = eb_unk_examples
